# %%
import pandas as pd

train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# Concatenar os DataFrames ao longo das colunas
df = pd.concat([train,test],axis=0)
df = df.loc[:,~df.columns.duplicated()]
# Verificar o número de linhas no DataFrame resultante
print("Número de linhas no DataFrame train:", len(train))
print("Número de linhas no DataFrame test:", len(test))
print("Número de linhas no DataFrame resultante:", len(df))
print(df.columns)
df.head()
# Out:
# Número de linhas no DataFrame train: 1460
# Número de linhas no DataFrame test: 1459
# Número de linhas no DataFrame resultante: 2919
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
# ...

# %%
colunas_traduzidas = [
    'Id', 'ClasseDeConstrução', 'Zoneamento', 'FrenteLote', 'AreaLote', 'Rua',
    'Viela', 'FormatoLote', 'ContornoTerreno', 'Utilidades', 'ConfigLote',
    'DeclividadeTerreno', 'Vizinhanca', 'Condicao1', 'Condicao2', 'TipoConstrucao',
    'EstiloCasa', 'QualidadeGeral', 'CondicaoGeral', 'AnoConstrucao', 'AnoRemodelacao',
    'EstiloTelhado', 'MaterialTelhado', 'ExteriorPrimario', 'ExteriorSecundario', 'TipoRevestimentoMasonryVeneer',
    'AreaRevestimentoMasonryVeneer', 'QualidadeExterior', 'CondicaoExterior', 'TipoFundacao', 'QualidadePorao',
    'CondicaoPorao', 'ExposicaoPorao', 'TipoAcabamentoPorao1', 'AreaAcabadaPorao1',
    'TipoAcabamentoPorao2', 'AreaAcabadaPorao2', 'AreaNaoAcabadaPorao', 'AreaTotalPorao', 'Aquecimento',
    'QualidadeAquecimento', 'ArCondicionadoCentral', 'Eletricidade', '1oAndarSF', '2oAndarSF',
    'AreaBaixaQualidadeAcabamento', 'AreaViva', 'BanheirosPorao', 'MeioBanheiroPorao', 'BanheirosCompletos',
    'MeioBanheiros', 'QuartosAcima', 'CozinhasAcima', 'QualidadeCozinha', 'TotalComodosAcima',
    'Funcionalidade', 'Lareiras', 'QualidadeLareira', 'TipoGaragem', 'AnoConstrucaoGaragem',
    'AcabamentoGaragem', 'CarrosGaragem', 'AreaGaragem', 'QualidadeGaragem', 'CondicaoGaragem',
    'Pavimentacao', 'DeckMadeiraSF', 'VarandaAbertaSF', 'VarandaFechadaSF',
    'Varanda3EstacoesSF', 'VarandaTelaSF', 'AreaPiscina', 'QualidadePiscina',
    'Cerca', 'RecursoDiverso', 'ValorRecursoDiverso', 'MesVenda', 'AnoVenda',
    'TipoVenda', 'CondicaoVenda', 'SalePrice'
]

train.columns = colunas_traduzidas

df.columns = colunas_traduzidas
df = df.drop(['Id'], axis=1)
print(df.columns)
# Out:
# Index(['ClasseDeConstrução', 'Zoneamento', 'FrenteLote', 'AreaLote', 'Rua',
#        'Viela', 'FormatoLote', 'ContornoTerreno', 'Utilidades', 'ConfigLote',
#        'DeclividadeTerreno', 'Vizinhanca', 'Condicao1', 'Condicao2',
#        'TipoConstrucao', 'EstiloCasa', 'QualidadeGeral', 'CondicaoGeral',
#        'AnoConstrucao', 'AnoRemodelacao', 'EstiloTelhado', 'MaterialTelhado',
#        'ExteriorPrimario', 'ExteriorSecundario',
#        'TipoRevestimentoMasonryVeneer', 'AreaRevestimentoMasonryVeneer',
#        'QualidadeExterior', 'CondicaoExterior', 'TipoFundacao',
#        'QualidadePorao', 'CondicaoPorao', 'ExposicaoPorao',
#        'TipoAcabamentoPorao1', 'AreaAcabadaPorao1', 'TipoAcabamentoPorao2',
#        'AreaAcabadaPorao2', 'AreaNaoAcabadaPorao', 'AreaTotalPorao',
#        'Aquecimento', 'QualidadeAquecimento', 'ArCondicionadoCentral',
#        'Eletricidade', '1oAndarSF', '2oAndarSF',
#        'AreaBaixaQualidadeAcabamento', 'AreaViva', 'BanheirosPorao',
# ...

# %%
colunas_traduzidas = [
    'Id', 'ClasseDeConstrução', 'Zoneamento', 'FrenteLote', 'AreaLote', 'Rua',
    'Viela', 'FormatoLote', 'ContornoTerreno', 'Utilidades', 'ConfigLote',
    'DeclividadeTerreno', 'Vizinhanca', 'Condicao1', 'Condicao2', 'TipoConstrucao',
    'EstiloCasa', 'QualidadeGeral', 'CondicaoGeral', 'AnoConstrucao', 'AnoRemodelacao',
    'EstiloTelhado', 'MaterialTelhado', 'ExteriorPrimario', 'ExteriorSecundario', 'TipoRevestimentoMasonryVeneer',
    'AreaRevestimentoMasonryVeneer', 'QualidadeExterior', 'CondicaoExterior', 'TipoFundacao', 'QualidadePorao',
    'CondicaoPorao', 'ExposicaoPorao', 'TipoAcabamentoPorao1', 'AreaAcabadaPorao1',
    'TipoAcabamentoPorao2', 'AreaAcabadaPorao2', 'AreaNaoAcabadaPorao', 'AreaTotalPorao', 'Aquecimento',
    'QualidadeAquecimento', 'ArCondicionadoCentral', 'Eletricidade', '1oAndarSF', '2oAndarSF',
    'AreaBaixaQualidadeAcabamento', 'AreaViva', 'BanheirosPorao', 'MeioBanheiroPorao', 'BanheirosCompletos',
    'MeioBanheiros', 'QuartosAcima', 'CozinhasAcima', 'QualidadeCozinha', 'TotalComodosAcima',
    'Funcionalidade', 'Lareiras', 'QualidadeLareira', 'TipoGaragem', 'AnoConstrucaoGaragem',
    'AcabamentoGaragem', 'CarrosGaragem', 'AreaGaragem', 'QualidadeGaragem', 'CondicaoGaragem',
    'Pavimentacao', 'DeckMadeiraSF', 'VarandaAbertaSF', 'VarandaFechadaSF',
    'Varanda3EstacoesSF', 'VarandaTelaSF', 'AreaPiscina', 'QualidadePiscina',
    'Cerca', 'RecursoDiverso', 'ValorRecursoDiverso', 'MesVenda', 'AnoVenda',
    'TipoVenda', 'CondicaoVenda'
]



test.columns = colunas_traduzidas

# %%
# Verificar valores NaN em cada coluna
nan_info = df.isnull().sum()

# Calcular a proporção de NaN em relação ao total de linhas
nan_ratio = nan_info / len(df)

# Criar um DataFrame para exibir as informações
nan_df = pd.DataFrame({
    'Coluna': nan_info.index,
    'Quantidade_NaN': nan_info.values,
    'Proporcao_NaN': nan_ratio.values
})

# Filtrar apenas as colunas com valores NaN
#nan_df = nan_df[nan_df['Quantidade_NaN'] > 0]
pd.set_option('display.max_rows', None)
# Visualizar o DataFrame resultante
display(nan_df)
pd.reset_option('display.max_rows', None)
# Out:
#                            Coluna  Quantidade_NaN  Proporcao_NaN
# 0              ClasseDeConstrução               0       0.000000
# 1                      Zoneamento               4       0.001370
# 2                      FrenteLote             486       0.166495
# 3                        AreaLote               0       0.000000
# 4                             Rua               0       0.000000
# 5                           Viela            2721       0.932169
# 6                     FormatoLote               0       0.000000
# 7                 ContornoTerreno               0       0.000000
# 8                      Utilidades               2       0.000685
# 9                      ConfigLote               0       0.000000
# 10             DeclividadeTerreno               0       0.000000
# 11                     Vizinhanca               0       0.000000
# 12                      Condicao1               0       0.000000
# ...

# %%
valores_unicos_qualidade_piscina = df['AreaPiscina'].unique()
contagem_valores_qualidade_piscina = df['AreaPiscina'].value_counts(dropna=False)
print(contagem_valores_qualidade_piscina)
print(valores_unicos_qualidade_piscina)

valores_unicos_qualidade_piscina = df['QualidadePiscina'].unique()
contagem_valores_qualidade_piscina = df['QualidadePiscina'].value_counts(dropna=False)
print(contagem_valores_qualidade_piscina)
print(valores_unicos_qualidade_piscina)
# Out:
# AreaPiscina
# 0      2906
# 512       1
# 648       1
# 576       1
# 555       1
# 480       1
# 519       1
# 738       1
# 144       1
# 368       1
# 444       1
# 228       1
# 561       1
# 800       1
# Name: count, dtype: int64
# [  0 512 648 576 555 480 519 738 144 368 444 228 561 800]
# QualidadePiscina
# NaN    2909
# Ex        4
# Gd        4
# Fa        2
# Name: count, dtype: int64
# [nan 'Ex' 'Fa' 'Gd']

# %%
df['QualidadePiscina'] = df['QualidadePiscina'].fillna(0)

# %%
# Substitua 'df' pelo nome real do seu DataFrame
df['StatusPiscina_Cluster'] = df['AreaPiscina'].astype(str) + '_' + df['QualidadePiscina'].astype(str)

# Exiba as primeiras linhas do DataFrame com a nova coluna
display(df[['AreaPiscina', 'QualidadePiscina', 'StatusPiscina_Cluster']].head())
# Out:
#    AreaPiscina QualidadePiscina StatusPiscina_Cluster
# 0            0                0                   0_0
# 1            0                0                   0_0
# 2            0                0                   0_0
# 3            0                0                   0_0
# 4            0                0                   0_0

# %%
# Exclua as colunas originais
df = df.drop(['AreaPiscina', 'QualidadePiscina'], axis=1)

valores_unicos_status_piscina = df['StatusPiscina_Cluster'].unique()
contagem_valores_status_piscina = df['StatusPiscina_Cluster'].value_counts(dropna=False)

print(contagem_valores_status_piscina)
print(valores_unicos_status_piscina)
# Out:
# StatusPiscina_Cluster
# 0_0       2906
# 512_Ex       1
# 648_Fa       1
# 576_Gd       1
# 555_Ex       1
# 480_Gd       1
# 519_Fa       1
# 738_Gd       1
# 144_Ex       1
# 368_0        1
# 444_0        1
# 228_Ex       1
# 561_0        1
# 800_Gd       1
# Name: count, dtype: int64
# ['0_0' '512_Ex' '648_Fa' '576_Gd' '555_Ex' '480_Gd' '519_Fa' '738_Gd'
#  '144_Ex' '368_0' '444_0' '228_Ex' '561_0' '800_Gd']

# %%
valores_unicos_tipo_garagem = df['TipoGaragem'].unique()
contagem_valores_tipo_garagem = df['TipoGaragem'].value_counts(dropna=False)
print(contagem_valores_tipo_garagem)
print(valores_unicos_tipo_garagem)

valores_unicos_anosgaragem = df['AnoConstrucaoGaragem'].unique()
contagem_valores_anosgaragem = df['AnoConstrucaoGaragem'].value_counts(dropna=False)
print(contagem_valores_anosgaragem)
print(valores_unicos_anosgaragem)
# Out:
# TipoGaragem
# Attchd     1723
# Detchd      779
# BuiltIn     186
# NaN         157
# Basment      36
# 2Types       23
# CarPort      15
# Name: count, dtype: int64
# ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan 'Basment' '2Types']
# AnoConstrucaoGaragem
# NaN       159
# 2005.0    142
# 2007.0    115
# 2006.0    115
# 2004.0     99
#          ...
# 1908.0      1
# 1896.0      1
# 1933.0      1
# 1906.0      1
# 1919.0      1
# Name: count, Length: 104, dtype: int64
# [2003. 1976. 2001. 1998. 2000. 1993. 2004. 1973. 1931. 1939. 1965. 2005.
#  1962. 2006. 1960. 1991. 1970. 1967. 1958. 1930. 2002. 1968. 2007. 2008.
#  1957. 1920. 1966. 1959. 1995. 1954. 1953.   nan 1983. 1977. 1997. 1985.
#  1963. 1981. 1964. 1999. 1935. 1990. 1945. 1987. 1989. 1915. 1956. 1948.
#  1974. 2009. 1950. 1961. 1921. 1900. 1979. 1951. 1969. 1936. 1975. 1971.
#  1923. 1984. 1926. 1955. 1986. 1988. 1916. 1932. 1972. 1918. 1980. 1924.
#  1996. 1940. 1949. 1994. 1910. 1978. 1982. 1992. 1925. 1941. 2010. 1927.
# ...

# %%
valores_unicos_acabamento_garagem = df['AcabamentoGaragem'].unique()
contagem_valores_acabamento_garagem = df['AcabamentoGaragem'].value_counts(dropna=False)
print(contagem_valores_acabamento_garagem)
print(valores_unicos_acabamento_garagem)

valores_unicos_carros_garagem = df['CarrosGaragem'].unique()
contagem_valores_carros_garagem = df['CarrosGaragem'].value_counts(dropna=False)
print(contagem_valores_carros_garagem)
print(valores_unicos_carros_garagem)

valores_unicos_area_garagem = df['AreaGaragem'].unique()
contagem_valores_area_garagem = df['AreaGaragem'].value_counts(dropna=False)
print(contagem_valores_area_garagem)
print(valores_unicos_area_garagem)
# Out:
# AcabamentoGaragem
# Unf    1230
# RFn     811
# Fin     719
# NaN     159
# Name: count, dtype: int64
# ['RFn' 'Unf' 'Fin' nan]
# CarrosGaragem
# 2.0    1594
# 1.0     776
# 3.0     374
# 0.0     157
# 4.0      16
# 5.0       1
# NaN       1
# Name: count, dtype: int64
# [ 2.  3.  1.  0.  4.  5. nan]
# AreaGaragem
# 0.0       157
# 576.0      97
# 440.0      96
# 240.0      69
# 484.0      68
#          ...
# 459.0       1
# 954.0       1
# 1014.0      1
# 753.0       1
# 272.0       1
# Name: count, Length: 604, dtype: int64
# [ 548.  460.  608.  642.  836.  480.  636.  484.  468.  205.  384.  736.
#   352.  840.  576.  516.  294.  853.  280.  534.  572.  270.  890.  772.
#   319.  240.  250.  271.  447.  556.  691.  672.  498.  246.    0.  440.
#   308.  504.  300.  670.  826.  386.  388.  528.  894.  565.  641.  288.
#   645.  852.  558.  220.  667.  360.  427.  490.  379.  297.  283.  509.
#   405.  758.  461.  400.  462.  420.  432.  506.  684.  472.  366.  476.
# ...

# %%
valores_unicos_qual_garagem = df['QualidadeGaragem'].unique()
contagem_valores_qual_garagem = df['QualidadeGaragem'].value_counts(dropna=False)
print(contagem_valores_qual_garagem)
print(valores_unicos_qual_garagem)

valores_unicos_cond_garagem = df['CondicaoGaragem'].unique()
contagem_valores_cond_garagem = df['CondicaoGaragem'].value_counts(dropna=False)
print(contagem_valores_cond_garagem)
print(valores_unicos_cond_garagem)
# Out:
# QualidadeGaragem
# TA     2604
# NaN     159
# Fa      124
# Gd       24
# Po        5
# Ex        3
# Name: count, dtype: int64
# ['TA' 'Fa' 'Gd' nan 'Ex' 'Po']
# CondicaoGaragem
# TA     2654
# NaN     159
# Fa       74
# Gd       15
# Po       14
# Ex        3
# Name: count, dtype: int64
# ['TA' 'Fa' nan 'Gd' 'Po' 'Ex']

# %%
# Substitua 'df' pelo nome real do seu DataFrame
df['AnoConstrucaoGaragem'] = df['AnoConstrucaoGaragem'].fillna(0)
df['TipoGaragem'] = df['TipoGaragem'].fillna(0)
df['AcabamentoGaragem'] = df['AcabamentoGaragem'].fillna(0)
df['QualidadeGaragem'] = df['QualidadeGaragem'].fillna(0)
df['CondicaoGaragem'] = df['CondicaoGaragem'].fillna(0)

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_verificar_nan = ['TipoGaragem', 'AnoConstrucaoGaragem', 'AcabamentoGaragem', 'CarrosGaragem', 'AreaGaragem', 'QualidadeGaragem', 'CondicaoGaragem']

# Verificar e contar NaN em cada coluna usada para criar 'StatusGaragem'
for coluna in colunas_verificar_nan:
    quantidade_nan = df[coluna].isna().sum()
    print(f"A coluna {coluna} tem {quantidade_nan} valores NaN.")
# Out:
# A coluna TipoGaragem tem 0 valores NaN.
# A coluna AnoConstrucaoGaragem tem 0 valores NaN.
# A coluna AcabamentoGaragem tem 0 valores NaN.
# A coluna CarrosGaragem tem 1 valores NaN.
# A coluna AreaGaragem tem 1 valores NaN.
# A coluna QualidadeGaragem tem 0 valores NaN.
# A coluna CondicaoGaragem tem 0 valores NaN.

# %%
# Substitua 'df' pelo nome real do seu DataFrame
df['StatusGaragem'] = (
    df['TipoGaragem'].astype(str) + '_' +
    df['AnoConstrucaoGaragem'].astype(str) + '_' +
    df['AcabamentoGaragem'].astype(str) + '_' +
    df['CarrosGaragem'].astype(str) + '_' +
    df['AreaGaragem'].astype(str) + '_' +
    df['QualidadeGaragem'].astype(str) + '_' +
    df['CondicaoGaragem'].astype(str)
)

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_status_garagem = df['StatusGaragem'].value_counts(dropna=False)
print("Contagem de valores para StatusGaragem:")
print(contagem_valores_status_garagem)

valores_unicos_status_garagem = df['StatusGaragem'].unique()
print("\nValores únicos para StatusGaragem:")
print(valores_unicos_status_garagem)

# Exclua as colunas originais associadas à garagem
df = df.drop(['TipoGaragem', 'AnoConstrucaoGaragem', 'AcabamentoGaragem', 'CarrosGaragem', 'AreaGaragem', 'QualidadeGaragem', 'CondicaoGaragem'], axis=1)

# Exiba as primeiras linhas do DataFrame com a nova coluna
print("\nDataFrame após a criação de StatusGaragem e exclusão das colunas originais:")
print(df.head())
# Out:
# Contagem de valores para StatusGaragem:
# StatusGaragem
# 0_0.0_0_0.0_0.0_0_0                  157
# Detchd_1973.0_Unf_1.0_264.0_TA_TA      8
# Attchd_2003.0_Fin_2.0_420.0_TA_TA      7
# Detchd_2000.0_Unf_2.0_440.0_TA_TA      7
# Detchd_1940.0_Unf_1.0_240.0_TA_TA      7
#                                     ...
# Detchd_1977.0_Fin_2.0_576.0_TA_TA      1
# Attchd_1946.0_Unf_2.0_492.0_TA_TA      1
# Attchd_1969.0_RFn_2.0_530.0_TA_TA      1
# Detchd_1974.0_Fin_1.0_396.0_TA_TA      1
# Attchd_1993.0_Fin_3.0_650.0_TA_TA      1
# Name: count, Length: 2437, dtype: int64
#
# Valores únicos para StatusGaragem:
# ['Attchd_2003.0_RFn_2.0_548.0_TA_TA' 'Attchd_1976.0_RFn_2.0_460.0_TA_TA'
#  'Attchd_2001.0_RFn_2.0_608.0_TA_TA' ...
#  'Attchd_1969.0_RFn_1.0_336.0_TA_TA' 'CarPort_1970.0_Unf_1.0_286.0_TA_TA'
#  'Attchd_1993.0_Fin_3.0_650.0_TA_TA']
#
# DataFrame após a criação de StatusGaragem e exclusão das colunas originais:
#    ClasseDeConstrução Zoneamento  FrenteLote  AreaLote   Rua Viela  \
# ...

# %%
from sklearn.cluster import KMeans

# Substitua 'df' pelo nome real do seu DataFrame
coluna_agrupamento1 = 'StatusGaragem'
num_clusters = 30  # Você pode ajustar o número de clusters conforme necessário

# Criar uma nova coluna com códigos de cluster
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df[coluna_agrupamento1 + '_Cluster'] = kmeans.fit_predict(df[coluna_agrupamento1].str.get_dummies('_'))

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_status_garagem = df['StatusGaragem_Cluster'].value_counts(dropna=False)
print("Contagem de valores para StatusGaragem_Cluster:")
print(contagem_valores_status_garagem)

valores_unicos_status_garagem = df['StatusGaragem_Cluster'].unique()
print("\nValores únicos para StatusGaragem_Cluster:")
print(valores_unicos_status_garagem)
# Out:
# C:\Users\psyte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Contagem de valores para StatusGaragem_Cluster:
# StatusGaragem_Cluster
# 10    440
# 8     284
# 9     271
# 5     228
# 23    218
# 16    199
# 4     159
# 26    133
# 12    120
# 13    115
# 15     96
# 6      68
# 11     65
# 24     58
# 28     50
# 17     49
# 18     45
# 19     36
# 20     33
# 25     32
# 27     29
# 22     29
# 3      28
# 1      26
# 21     22
# 29     22
# 14     21
# 7      17
# 2      14
# 0      12
# Name: count, dtype: int64
#
# Valores únicos para StatusGaragem_Cluster:
# [10  2 13 23  1 24 12  9 15  6  8  5 28 11 18 29  4 26 16  3 25 20 17 22
#  19 27  7 21 14  0]

# %%
valores_unicos_deck_garagem = df['DeckMadeiraSF'].unique()
contagem_valores_deck_garagem = df['DeckMadeiraSF'].value_counts(dropna=False)
print(contagem_valores_deck_garagem)
print(valores_unicos_deck_garagem)
# Out:
# DeckMadeiraSF
# 0      1523
# 100      74
# 192      70
# 144      61
# 168      56
#        ...
# 436       1
# 448       1
# 361       1
# 362       1
# 530       1
# Name: count, Length: 379, dtype: int64
# [   0  298  192   40  255  235   90  147  140  160   48  240  171  100
#   406  222  288   49  203  113  392  145  196  168  112  106  857  115
#   120   12  576  301  144  300   74  127  232  158  352  182  180  166
#   224   80  367   53  188  105   24   98  276  200  409  239  400  476
#   178  574  237  210  441  116  280  104   87  132  238  149  355   60
#   139  108  351  209  216  248  143  365  370   58  197  263  123  138
#   333  250  292   95  262   81  289  124  172  110  208  468  256  302
#   190  340  233  184  201  142  122  155  670  135  495  536  306   64
#   364  353   66  159  146  296  125   44  215  264   88   89   96  414
#   519  206  141  260  324  156  220   38  261  126   85  466  270   78
# ...

# %%
valores_unicos_varab_garagem = df['VarandaAbertaSF'].unique()
contagem_valores_varab_garagem = df['VarandaAbertaSF'].value_counts(dropna=False)
print(contagem_valores_varab_garagem)
print(valores_unicos_varab_garagem)
# Out:
# VarandaAbertaSF
# 0      1298
# 36       52
# 48       51
# 40       44
# 32       38
#        ...
# 229       1
# 205       1
# 263       1
# 213       1
# 225       1
# Name: count, Length: 252, dtype: int64
# [ 61   0  42  35  84  30  57 204   4  21  33 213 112 102 154 159 110  90
#   56  32  50 258  54  65  38  47  64  52 138 104  82  43 146  75  72  70
#   49  11  36 151  29  94 101 199  99 234 162  63  68  46  45 122 184 120
#   20  24 130 205 108  80  66  48  25  96 111 106  40 114   8 136 132  62
#  228  60 238 260  27  74  16 198  26  83  34  55  22  98 172 119 208 105
#  140 168  28  39 148  12  51 150 117 250  10  81  44 144 175 195 128  76
#   17  59 214 121  53 231 134 192 123  78 187  85 133 176 113 137 125 523
#  100 285  88 406 155  73 182 502 274 158 142 243 235 312 124 267 265  87
#  288  23 152 341 116 160 174 247 291  18 170 156 166 129 418 240  77 364
#  188 207  67  69 131 191  41 118 252 189 282 135  95 224 169 319  58  93
# ...

# %%
valores_unicos_varfec_garagem = df['VarandaFechadaSF'].unique()
contagem_valores_varfec_garagem = df['VarandaFechadaSF'].value_counts(dropna=False)
print(contagem_valores_varfec_garagem)
print(valores_unicos_varfec_garagem)
# Out:
# VarandaFechadaSF
# 0      2460
# 112      22
# 96       13
# 144      11
# 192      10
#        ...
# 214       1
# 220       1
# 19        1
# 174       1
# 23        1
# Name: count, Length: 183, dtype: int64
# [   0  272  228  205  176   87  172  102   37  144   64  114  202  128
#   156   44   77  192  140  180  183   39  184   40  552   30  126   96
#    60  150  120  112  252   52  224  234  244  268  137   24  108  294
#   177  218  242   91  160  130  169  105   34  248  236   32   80  115
#   291  116  158  210   36  200   84  148  136  240   54  100  189  293
#   164  216  239   67   90   56  129   98  143   70  386  154  185  134
#   196  264  275  230  254   68  194  318   48   94  138  226  174   19
#   170  220  214  280  190  330  208  145  259   81   42  123  162  286
#   168   20  301  198  221  212   50   99  186  113  135  334  246   18
#    41   35  364   45   86  265  222  209  260  203  432   25  238   51
# ...

# %%
valores_unicos_var3_garagem = df['Varanda3EstacoesSF'].unique()
contagem_valores_var3_garagem = df['Varanda3EstacoesSF'].value_counts(dropna=False)
print(contagem_valores_var3_garagem)
print(valores_unicos_var3_garagem)
# Out:
# Varanda3EstacoesSF
# 0      2882
# 168       3
# 153       3
# 144       2
# 216       2
# 180       2
# 140       1
# 86        1
# 176       1
# 219       1
# 120       1
# 174       1
# 150       1
# 360       1
# 225       1
# 255       1
# 224       1
# 304       1
# 290       1
# 407       1
# 96        1
# 320       1
# 23        1
# 162       1
# 182       1
# 130       1
# 196       1
# 245       1
# 238       1
# 508       1
# 323       1
# Name: count, dtype: int64
# [  0 320 407 130 180 168 140 508 238 245 196 144 182 162  23 216  96 153
#  290 304 224 255 225 360 150 174 120 219 176  86 323]

# %%
valores_unicos_vartel_garagem = df['VarandaTelaSF'].unique()
contagem_valores_vartel_garagem = df['VarandaTelaSF'].value_counts(dropna=False)
print(contagem_valores_vartel_garagem)
print(valores_unicos_vartel_garagem)
# Out:
# VarandaTelaSF
# 0      2663
# 144      13
# 192      11
# 168      10
# 120       9
#        ...
# 233       1
# 190       1
# 265       1
# 222       1
# 104       1
# Name: count, Length: 121, dtype: int64
# [  0 176 198 291 252  99 184 168 130 142 192 410 224 266 170 154 153 144
#  128 259 160 271 234 374 185 182  90 396 140 276 180 161 145 200 122  95
#  120  60 126 189 260 147 385 287 156 100 216 210 197 204 225 152 175 312
#  222 265 322 190 233  63  53 143 273 288 263  80 163 116 480 178 440 155
#  220 119 165  40 256 240 148 166 108 490 196 121  92 342 255 111 112 231
#  110 117 195 115 141 208  94 164  64 576 227 221 171 135 174 217 201 109
#  150  84 228 138  88 280 123 264 270 162 348 113 104]

# %%
valores_unicos_ban = df['BanheirosPorao'].unique()
contagem_valores_ban = df['BanheirosPorao'].value_counts(dropna=False)
print(contagem_valores_ban)
print(valores_unicos_ban)
# Out:
# BanheirosPorao
# 0.0    1705
# 1.0    1172
# 2.0      38
# 3.0       2
# NaN       2
# Name: count, dtype: int64
# [ 1.  0.  2.  3. nan]

# %%
valores_unicos_banmeio = df['MeioBanheiroPorao'].unique()
contagem_valores_ban = df['MeioBanheiroPorao'].value_counts(dropna=False)
print(contagem_valores_ban)
print(valores_unicos_banmeio)
# Out:
# MeioBanheiroPorao
# 0.0    2742
# 1.0     171
# 2.0       4
# NaN       2
# Name: count, dtype: int64
# [ 0.  1.  2. nan]

# %%
valores_unicos_bancom = df['BanheirosCompletos'].unique()
contagem_valores_ban = df['BanheirosCompletos'].value_counts(dropna=False)
print(contagem_valores_ban)
print(valores_unicos_bancom)

valores_unicos_banmeios = df['MeioBanheiros'].unique()
contagem_valores_ban = df['MeioBanheiros'].value_counts(dropna=False)
print(contagem_valores_ban)
print(valores_unicos_banmeios)
# Out:
# BanheirosCompletos
# 2    1530
# 1    1309
# 3      64
# 0      12
# 4       4
# Name: count, dtype: int64
# [2 1 3 0 4]
# MeioBanheiros
# 0    1834
# 1    1060
# 2      25
# Name: count, dtype: int64
# [1 0 2]

# %%
valores_unicos_qualpor= df['QualidadePorao'].unique()
contagem_valores_ban = df['QualidadePorao'].value_counts(dropna=False)
print(contagem_valores_ban)
print(valores_unicos_qualpor)

valores_unicos_condpor = df['CondicaoPorao'].unique()
contagem_valores_ban = df['CondicaoPorao'].value_counts(dropna=False)
print(contagem_valores_ban)
print(valores_unicos_condpor)
# Out:
# QualidadePorao
# TA     1283
# Gd     1209
# Ex      258
# Fa       88
# NaN      81
# Name: count, dtype: int64
# ['Gd' 'TA' 'Ex' nan 'Fa']
# CondicaoPorao
# TA     2606
# Gd      122
# Fa      104
# NaN      82
# Po        5
# Name: count, dtype: int64
# ['TA' 'Gd' nan 'Fa' 'Po']

# %%
valores_unicos_expo= df['ExposicaoPorao'].unique()
contagem_valores_expo = df['ExposicaoPorao'].value_counts(dropna=False)
print(contagem_valores_expo)
print(valores_unicos_expo)

valores_unicos_tip= df['TipoAcabamentoPorao1'].unique()
contagem_valores_tip = df['TipoAcabamentoPorao1'].value_counts(dropna=False)
print(contagem_valores_tip)
print(valores_unicos_tip)
# Out:
# ExposicaoPorao
# No     1904
# Av      418
# Gd      276
# Mn      239
# NaN      82
# Name: count, dtype: int64
# ['No' 'Gd' 'Mn' 'Av' nan]
# TipoAcabamentoPorao1
# Unf    851
# GLQ    849
# ALQ    429
# Rec    288
# BLQ    269
# LwQ    154
# NaN     79
# Name: count, dtype: int64
# ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' nan 'LwQ']

# %%
valores_unicos_areatot= df['AreaTotalPorao'].unique()
contagem_valores_areatot = df['AreaTotalPorao'].value_counts(dropna=False)
print(contagem_valores_areatot)
print(valores_unicos_areatot)
# Out:
# AreaTotalPorao
# 0.0       78
# 864.0     74
# 672.0     29
# 912.0     26
# 1040.0    25
#           ..
# 1571.0     1
# 2633.0     1
# 757.0      1
# 873.0      1
# 1381.0     1
# Name: count, Length: 1059, dtype: int64
# [ 856. 1262.  920. ...  498.  432. 1381.]

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_verificar_nan = ['QualidadePorao', 'CondicaoPorao', 'ExposicaoPorao', 'TipoAcabamentoPorao1', 'TipoAcabamentoPorao2']

# Verificar e contar NaN em cada coluna usada para criar 'MediaPorao'
for coluna in colunas_verificar_nan:
    quantidade_nan = df[coluna].isna().sum()
    print(f"A coluna {coluna} tem {quantidade_nan} valores NaN.")
# Out:
# A coluna QualidadePorao tem 81 valores NaN.
# A coluna CondicaoPorao tem 82 valores NaN.
# A coluna ExposicaoPorao tem 82 valores NaN.
# A coluna TipoAcabamentoPorao1 tem 79 valores NaN.
# A coluna TipoAcabamentoPorao2 tem 80 valores NaN.

# %%
# Substitua 'df' pelo nome real do seu DataFrame
df['QualidadePorao'] = df['QualidadePorao'].fillna(0)
df['CondicaoPorao'] = df['CondicaoPorao'].fillna(0)
df['ExposicaoPorao'] = df['ExposicaoPorao'].fillna(0)
df['TipoAcabamentoPorao1'] = df['TipoAcabamentoPorao1'].fillna(0)
df['TipoAcabamentoPorao2'] = df['TipoAcabamentoPorao2'].fillna(0)

# %%
# Lista das colunas do porão
colunas_porao2 = ['QualidadePorao', 'CondicaoPorao', 'ExposicaoPorao', 'TipoAcabamentoPorao1', 'TipoAcabamentoPorao2' ]

# Criar uma nova coluna com a concatenação dos valores das colunas do porão
df['MediaPorao'] = df[colunas_porao2].astype(str).apply('_'.join, axis=1)

# Excluir colunas originais do porão
df = df.drop(colunas_porao2, axis=1)

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_media_porao = df['MediaPorao'].value_counts(dropna=False)
print("Contagem de valores para MediaPorao:")
print(contagem_valores_media_porao)

valores_unicos_media_porao = df['MediaPorao'].unique()
print("\nValores únicos para MediaPorao:")
print(valores_unicos_media_porao)
# Out:
# Contagem de valores para MediaPorao:
# MediaPorao
# TA_TA_No_Unf_Unf    304
# Gd_TA_No_Unf_Unf    255
# Gd_TA_No_GLQ_Unf    242
# TA_TA_No_Rec_Unf    153
# TA_TA_No_ALQ_Unf    150
#                    ...
# TA_TA_Gd_Rec_LwQ      1
# Ex_TA_Mn_BLQ_GLQ      1
# Gd_TA_Av_BLQ_ALQ      1
# TA_Gd_Gd_ALQ_Rec      1
# Gd_TA_Av_LwQ_Unf      1
# Name: count, Length: 262, dtype: int64
#
# Valores únicos para MediaPorao:
# ['Gd_TA_No_GLQ_Unf' 'Gd_TA_Gd_ALQ_Unf' 'Gd_TA_Mn_GLQ_Unf'
#  'TA_Gd_No_ALQ_Unf' 'Gd_TA_Av_GLQ_Unf' 'Ex_TA_Av_GLQ_Unf'
#  'Gd_TA_Mn_ALQ_BLQ' 'TA_TA_No_Unf_Unf' 'TA_TA_No_GLQ_Unf'
#  'TA_TA_No_Rec_Unf' 'Ex_TA_No_GLQ_Unf' 'TA_TA_No_ALQ_Unf'
#  'Gd_TA_Av_Unf_Unf' 'TA_TA_No_BLQ_Unf' '0_0_0_0_0' 'TA_TA_No_LwQ_Unf'
#  'Ex_TA_Av_Unf_Unf' 'Gd_TA_No_Unf_Unf' 'TA_TA_Mn_Rec_ALQ'
#  'TA_TA_Mn_BLQ_Rec' 'TA_TA_Gd_BLQ_Unf' 'Gd_TA_Av_ALQ_LwQ'
#  'Gd_TA_Av_LwQ_BLQ' 'TA_TA_No_ALQ_BLQ' 'Gd_TA_Gd_LwQ_GLQ'
#  'Ex_TA_Gd_GLQ_Unf' 'Ex_TA_Gd_Unf_Unf' 'TA_TA_Av_ALQ_Unf'
# ...

# %%
# Substitua 'df' pelo nome real do seu DataFrame
coluna_agrupamento4 = 'MediaPorao'
num_clusters = 20  # Você pode ajustar o número de clusters conforme necessário

# Criar uma nova coluna com códigos de cluster
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df[coluna_agrupamento4 + '_Cluster'] = kmeans.fit_predict(df[coluna_agrupamento4].str.get_dummies('_'))

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_status_porao = df['MediaPorao_Cluster'].value_counts(dropna=False)
print("Contagem de valores para MediaPorao_Cluster:")
print(contagem_valores_status_porao)

valores_unicos_status_porao = df['MediaPorao_Cluster'].unique()
print("\nValores únicos para MediaPorao_Cluster:")
print(valores_unicos_status_porao)
# Out:
# Contagem de valores para MediaPorao_Cluster:
# MediaPorao_Cluster
# 1     379
# 5     317
# 0     264
# 4     206
# 6     200
# 3     199
# 12    176
# 2     151
# 8     130
# 16    118
# 17    112
# 18     94
# 11     84
# 9      83
# 10     80
# 7      79
# 14     66
# 19     65
# 13     63
# 15     53
# Name: count, dtype: int64
#
# Valores únicos para MediaPorao_Cluster:
# [ 0 17  2  4  9 13  1 11  6  3 12  7  5 15 19 14 18 10 16  8]
# C:\Users\psyte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
valores_unicos_viz=df['Vizinhanca'].unique()
contagem_valores_viz = df['Vizinhanca'].value_counts(dropna=False)
print(contagem_valores_viz)
print(valores_unicos_viz)
# Out:
# Vizinhanca
# NAmes      443
# CollgCr    267
# OldTown    239
# Edwards    194
# Somerst    182
# NridgHt    166
# Gilbert    165
# Sawyer     151
# NWAmes     131
# SawyerW    125
# Mitchel    114
# BrkSide    108
# Crawfor    103
# IDOTRR      93
# Timber      72
# NoRidge     71
# StoneBr     51
# SWISU       48
# ClearCr     44
# MeadowV     37
# BrDale      30
# Blmngtn     28
# Veenker     24
# NPkVill     23
# Blueste     10
# Name: count, dtype: int64
# ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']

# %%
valores_unicos_cond1= df['Condicao1'].unique()
contagem_valores_cond1 = df['Condicao1'].value_counts(dropna=False)
print(contagem_valores_cond1)
print(valores_unicos_cond1)

valores_unicos_cond2= df['Condicao2'].unique()
contagem_valores_cond2 = df['Condicao2'].value_counts(dropna=False)
print(contagem_valores_cond2)
print(valores_unicos_cond2)
# Out:
# Condicao1
# Norm      2511
# Feedr      164
# Artery      92
# RRAn        50
# PosN        39
# RRAe        28
# PosA        20
# RRNn         9
# RRNe         6
# Name: count, dtype: int64
# ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
# Condicao2
# Norm      2889
# Feedr       13
# Artery       5
# PosN         4
# PosA         4
# RRNn         2
# RRAn         1
# RRAe         1
# Name: count, dtype: int64
# ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_verificar_nan = ['Vizinhanca', 'Condicao1', 'Condicao2']

# Verificar e contar NaN em cada coluna usada para criar 'Local'
for coluna in colunas_verificar_nan:
    quantidade_nan = df[coluna].isna().sum()
    print(f"A coluna {coluna} tem {quantidade_nan} valores NaN.")
# Out:
# A coluna Vizinhanca tem 0 valores NaN.
# A coluna Condicao1 tem 0 valores NaN.
# A coluna Condicao2 tem 0 valores NaN.

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_local1 = ['Vizinhanca', 'Condicao1', 'Condicao2']

# Criar uma nova coluna com a combinação das colunas de local
df['AgrupamentoLocal'] = df[colunas_local1].astype(str).apply('_'.join, axis=1)

# Excluir colunas originais do porão
df = df.drop(colunas_local1, axis=1)

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_agrupamento_local = df['AgrupamentoLocal'].value_counts(dropna=False)
print("Contagem de valores para AgrupamentoLocal:")
print(contagem_valores_agrupamento_local)

valores_unicos_agrupamento_local = df['AgrupamentoLocal'].unique()
print("\nValores únicos para AgrupamentoLocal:")
print(valores_unicos_agrupamento_local)
# Out:
# Contagem de valores para AgrupamentoLocal:
# AgrupamentoLocal
# NAmes_Norm_Norm       369
# CollgCr_Norm_Norm     259
# OldTown_Norm_Norm     184
# Edwards_Norm_Norm     174
# NridgHt_Norm_Norm     161
#                      ...
# NridgHt_PosN_PosN       1
# Sawyer_PosN_Norm        1
# NWAmes_Feedr_RRAn       1
# Crawfor_PosN_Norm       1
# Sawyer_Feedr_Feedr      1
# Name: count, Length: 100, dtype: int64
#
# Valores únicos para AgrupamentoLocal:
# ['CollgCr_Norm_Norm' 'Veenker_Feedr_Norm' 'Crawfor_Norm_Norm'
#  'NoRidge_Norm_Norm' 'Mitchel_Norm_Norm' 'Somerst_Norm_Norm'
#  'NWAmes_PosN_Norm' 'OldTown_Artery_Norm' 'BrkSide_Artery_Artery'
#  'Sawyer_Norm_Norm' 'NridgHt_Norm_Norm' 'NAmes_Norm_Norm'
#  'BrkSide_Norm_Norm' 'SawyerW_RRAe_Norm' 'IDOTRR_Norm_Norm'
#  'MeadowV_Norm_Norm' 'BrkSide_Feedr_RRNn' 'IDOTRR_Feedr_Norm'
#  'Edwards_Norm_Norm' 'Timber_Norm_Norm' 'SawyerW_Norm_Norm'
#  'OldTown_Norm_Norm' 'Gilbert_Norm_Norm' 'IDOTRR_RRNn_Norm'
# ...

# %%
# Substitua 'df' pelo nome real do seu DataFrame
coluna_agrupamento5 = 'AgrupamentoLocal'
num_clusters = 30  # Você pode ajustar o número de clusters conforme necessário

# Criar uma nova coluna com códigos de cluster
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df[coluna_agrupamento5 + '_Cluster'] = kmeans.fit_predict(df[coluna_agrupamento5].str.get_dummies('_'))

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_status_local = df['AgrupamentoLocal_Cluster'].value_counts(dropna=False)
print("Contagem de valores para AgrupamentoLocal_Cluster:")
print(contagem_valores_status_local)

valores_unicos_status_local = df['AgrupamentoLocal_Cluster'].unique()
print("\nValores únicos para AgrupamentoLocal_Cluster:")
print(valores_unicos_status_local)
# Out:
# Contagem de valores para AgrupamentoLocal_Cluster:
# AgrupamentoLocal_Cluster
# 1     383
# 2     267
# 3     197
# 0     194
# 4     182
# 5     166
# 6     148
# 8     131
# 13    125
# 11    114
# 10    108
# 14    104
# 9     103
# 12     93
# 15     72
# 16     71
# 19     58
# 17     51
# 21     44
# 24     42
# 18     37
# 28     32
# 27     31
# 22     30
# 26     29
# 23     28
# 25     24
# 20     23
# 29     17
# 7      15
# Name: count, dtype: int64
#
# Valores únicos para AgrupamentoLocal_Cluster:
# [ 2 25  9 16 11  4  8 24 10 14  5  1 13 12 18  0 15  3  6 17 21 20 26  7
#  23 22 28 19 27 29]
# C:\Users\psyte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
valores_unicos_aque= df['Aquecimento'].unique()
contagem_valores_aque = df['Aquecimento'].value_counts(dropna=False)
print(contagem_valores_aque)
print(valores_unicos_aque)

valores_unicos_qual= df['QualidadeAquecimento'].unique()
contagem_valores_qual = df['QualidadeAquecimento'].value_counts(dropna=False)
print(contagem_valores_qual)
print(valores_unicos_qual)
# Out:
# Aquecimento
# GasA     2874
# GasW       27
# Grav        9
# Wall        6
# OthW        2
# Floor       1
# Name: count, dtype: int64
# ['GasA' 'GasW' 'Grav' 'Wall' 'OthW' 'Floor']
# QualidadeAquecimento
# Ex    1493
# TA     857
# Gd     474
# Fa      92
# Po       3
# Name: count, dtype: int64
# ['Ex' 'Gd' 'TA' 'Fa' 'Po']

# %%
valores_unicos_aquec= df['ArCondicionadoCentral'].unique()
contagem_valores_aquec = df['ArCondicionadoCentral'].value_counts(dropna=False)
print(contagem_valores_aquec)
print(valores_unicos_aquec)

valores_unicos_ele= df['Eletricidade'].unique()
contagem_valores_ele = df['Eletricidade'].value_counts(dropna=False)
print(contagem_valores_ele)
print(valores_unicos_ele)
# Out:
# ArCondicionadoCentral
# Y    2723
# N     196
# Name: count, dtype: int64
# ['Y' 'N']
# Eletricidade
# SBrkr    2671
# FuseA     188
# FuseF      50
# FuseP       8
# Mix         1
# NaN         1
# Name: count, dtype: int64
# ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix' nan]

# %%
# Substitua 'df' pelo nome real do seu DataFrame
coluna_preencher_com_moda = 'Eletricidade'

# Calcula a moda
moda = df[coluna_preencher_com_moda].mode()[0]

# Preenche os valores NaN com a moda
df[coluna_preencher_com_moda] = df[coluna_preencher_com_moda].fillna(moda)

valores_unicos_ele= df['Eletricidade'].unique()
contagem_valores_ele = df['Eletricidade'].value_counts(dropna=False)
print(contagem_valores_ele)
print(valores_unicos_ele)
# Out:
# Eletricidade
# SBrkr    2672
# FuseA     188
# FuseF      50
# FuseP       8
# Mix         1
# Name: count, dtype: int64
# ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix']

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_aquecimento1 = ['Aquecimento', 'QualidadeAquecimento', 'ArCondicionadoCentral', 'Eletricidade']

# Criar uma nova coluna com a combinação das colunas de aquecimento
df['AgrupamentoAquecimento'] = df[colunas_aquecimento1].astype(str).apply('_'.join, axis=1)

# Excluir colunas originais do porão
df = df.drop(colunas_aquecimento1, axis=1)

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_agrupamento_aquecimento = df['AgrupamentoAquecimento'].value_counts(dropna=False)
print("Contagem de valores para AgrupamentoAquecimento:")
print(contagem_valores_agrupamento_aquecimento)

valores_unicos_agrupamento_aquecimento = df['AgrupamentoAquecimento'].unique()
print("\nValores únicos para AgrupamentoAquecimento:")
print(valores_unicos_agrupamento_aquecimento)
# Out:
# Contagem de valores para AgrupamentoAquecimento:
# AgrupamentoAquecimento
# GasA_Ex_Y_SBrkr     1434
# GasA_TA_Y_SBrkr      675
# GasA_Gd_Y_SBrkr      402
# GasA_TA_Y_FuseA       59
# GasA_TA_N_SBrkr       51
# GasA_Fa_Y_SBrkr       44
# GasA_Ex_Y_FuseA       37
# GasA_Gd_Y_FuseA       35
# GasA_TA_N_FuseA       27
# GasA_Gd_N_SBrkr       16
# GasA_TA_N_FuseF       14
# GasA_Fa_N_SBrkr       13
# GasA_Ex_N_SBrkr        9
# GasA_Gd_N_FuseA        9
# GasW_TA_N_SBrkr        9
# GasA_TA_Y_FuseF        9
# GasA_Fa_Y_FuseA        6
# GasW_TA_Y_SBrkr        5
# GasA_Ex_Y_FuseF        5
# GasA_Gd_Y_FuseF        5
# Grav_Fa_N_FuseA        4
# GasW_Fa_N_SBrkr        4
# Grav_Fa_N_FuseF        3
# GasA_Fa_N_FuseP        3
# GasA_Fa_N_FuseA        3
# GasA_Ex_N_FuseA        3
# GasA_Ex_N_FuseF        3
# GasA_Fa_N_FuseF        3
# Grav_Fa_N_SBrkr        2
# GasW_Gd_Y_SBrkr        2
# GasA_Gd_N_FuseP        2
# Wall_Fa_N_FuseF        2
# Wall_Fa_N_FuseA        2
# OthW_Fa_N_SBrkr        2
# ...

# %%
# Substitua 'df' pelo nome real do seu DataFrame
coluna_agrupamento6 = 'AgrupamentoAquecimento'
num_clusters = 15  # Você pode ajustar o número de clusters conforme necessário

# Criar uma nova coluna com códigos de cluster
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df[coluna_agrupamento6 + '_Cluster'] = kmeans.fit_predict(df[coluna_agrupamento6].str.get_dummies('_'))

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_status_aquec = df['AgrupamentoAquecimento_Cluster'].value_counts(dropna=False)
print("Contagem de valores para AgrupamentoAquecimento_Cluster:")
print(contagem_valores_status_aquec)

valores_unicos_status_aquec = df['AgrupamentoAquecimento_Cluster'].unique()
print("\nValores únicos para AgrupamentoAquecimento_Cluster:")
print(valores_unicos_status_aquec)
# Out:
# Contagem de valores para AgrupamentoAquecimento_Cluster:
# AgrupamentoAquecimento_Cluster
# 1     1435
# 2      675
# 0      404
# 5       61
# 6       61
# 4       50
# 3       42
# 9       37
# 7       36
# 12      24
# 14      20
# 13      20
# 8       18
# 10      18
# 11      18
# Name: count, dtype: int64
#
# Valores únicos para AgrupamentoAquecimento_Cluster:
# [ 1  0 14  2  9  8  5  3 13 10  6  4 12  7 11]
# C:\Users\psyte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
valores_unicos_est= df['EstiloTelhado'].unique()
contagem_valores_est = df['EstiloTelhado'].value_counts(dropna=False)
print(contagem_valores_est)
print(valores_unicos_est)

valores_unicos_mat= df['MaterialTelhado'].unique()
contagem_valores_mat = df['MaterialTelhado'].value_counts(dropna=False)
print(contagem_valores_mat)
print(valores_unicos_mat)
# Out:
# EstiloTelhado
# Gable      2310
# Hip         551
# Gambrel      22
# Flat         20
# Mansard      11
# Shed          5
# Name: count, dtype: int64
# ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
# MaterialTelhado
# CompShg    2876
# Tar&Grv      23
# WdShake       9
# WdShngl       7
# Metal         1
# Membran       1
# Roll          1
# ClyTile       1
# Name: count, dtype: int64
# ['CompShg' 'WdShngl' 'Metal' 'WdShake' 'Membran' 'Tar&Grv' 'Roll'
#  'ClyTile']

# %%
valores_unicos_extp= df['ExteriorPrimario'].unique()
contagem_valores_extp = df['ExteriorPrimario'].value_counts(dropna=False)
print(contagem_valores_extp)
print(valores_unicos_extp)

valores_unicos_exts= df['ExteriorSecundario'].unique()
contagem_valores_exts = df['ExteriorSecundario'].value_counts(dropna=False)
print(contagem_valores_exts)
print(valores_unicos_exts)
# Out:
# ExteriorPrimario
# VinylSd    1025
# MetalSd     450
# HdBoard     442
# Wd Sdng     411
# Plywood     221
# CemntBd     126
# BrkFace      87
# WdShing      56
# AsbShng      44
# Stucco       43
# BrkComm       6
# AsphShn       2
# Stone         2
# CBlock        2
# ImStucc       1
# NaN           1
# Name: count, dtype: int64
# ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'AsbShng' 'Stucco' 'BrkComm' 'AsphShn' 'Stone' 'ImStucc'
#  'CBlock' nan]
# ExteriorSecundario
# VinylSd    1014
# MetalSd     447
# HdBoard     406
# Wd Sdng     391
# Plywood     270
# CmentBd     126
# Wd Shng      81
# Stucco       47
# BrkFace      47
# AsbShng      38
# Brk Cmn      22
# ImStucc      15
# Stone         6
# AsphShn       4
# CBlock        3
# Other         1
# NaN           1
# Name: count, dtype: int64
# ['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood' 'Wd Sdng' 'CmentBd'
#  'BrkFace' 'Stucco' 'AsbShng' 'Brk Cmn' 'ImStucc' 'AsphShn' 'Stone'
# ...

# %%
valores_unicos_tip= df['TipoRevestimentoMasonryVeneer'].unique()
contagem_valores_tip = df['TipoRevestimentoMasonryVeneer'].value_counts(dropna=False)
print(contagem_valores_tip)
print(valores_unicos_tip)

valores_unicos_are= df['AreaRevestimentoMasonryVeneer'].unique()
contagem_valores_are = df['AreaRevestimentoMasonryVeneer'].value_counts(dropna=False)
print(contagem_valores_are)
print(valores_unicos_are)
# Out:
# TipoRevestimentoMasonryVeneer
# NaN        1766
# BrkFace     879
# Stone       249
# BrkCmn       25
# Name: count, dtype: int64
# ['BrkFace' nan 'Stone' 'BrkCmn']
# AreaRevestimentoMasonryVeneer
# 0.0      1738
# NaN        23
# 120.0      15
# 176.0      13
# 200.0      13
#          ...
# 788.0       1
# 796.0       1
# 391.0       1
# 604.0       1
# 382.0       1
# Name: count, Length: 445, dtype: int64
# [1.960e+02 0.000e+00 1.620e+02 3.500e+02 1.860e+02 2.400e+02 2.860e+02
#  3.060e+02 2.120e+02 1.800e+02 3.800e+02 2.810e+02 6.400e+02 2.000e+02
#  2.460e+02 1.320e+02 6.500e+02 1.010e+02 4.120e+02 2.720e+02 4.560e+02
#  1.031e+03 1.780e+02 5.730e+02 3.440e+02 2.870e+02 1.670e+02 1.115e+03
#  4.000e+01 1.040e+02 5.760e+02 4.430e+02 4.680e+02 6.600e+01 2.200e+01
#  2.840e+02 7.600e+01 2.030e+02 6.800e+01 1.830e+02 4.800e+01 2.800e+01
#  3.360e+02 6.000e+02 7.680e+02 4.800e+02 2.200e+02 1.840e+02 1.129e+03
#  1.160e+02 1.350e+02 2.660e+02 8.500e+01 3.090e+02 1.360e+02 2.880e+02
# ...

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_verificar_nan = ['EstiloTelhado', 'MaterialTelhado', 'ExteriorPrimario', 'ExteriorSecundario', 'TipoRevestimentoMasonryVeneer', 'AreaRevestimentoMasonryVeneer']

# Verificar e contar NaN em cada coluna usada para criar 'Local'
for coluna in colunas_verificar_nan:
    quantidade_nan = df[coluna].isna().sum()
    print(f"A coluna {coluna} tem {quantidade_nan} valores NaN.")
# Out:
# A coluna EstiloTelhado tem 0 valores NaN.
# A coluna MaterialTelhado tem 0 valores NaN.
# A coluna ExteriorPrimario tem 1 valores NaN.
# A coluna ExteriorSecundario tem 1 valores NaN.
# A coluna TipoRevestimentoMasonryVeneer tem 1766 valores NaN.
# A coluna AreaRevestimentoMasonryVeneer tem 23 valores NaN.

# %%
# Substitua 'df' pelo nome real do seu DataFrame
df['TipoRevestimentoMasonryVeneer'] = df['TipoRevestimentoMasonryVeneer'].fillna(0)
df['AreaRevestimentoMasonryVeneer'] = df['AreaRevestimentoMasonryVeneer'].fillna(0)

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_revestimentoma = [ 'TipoRevestimentoMasonryVeneer', 'AreaRevestimentoMasonryVeneer']

# Criar uma nova coluna com a concatenação dos valores das colunas de revestimento
df['RevestimentoMa'] = df[colunas_revestimentoma].astype(str).agg('_'.join, axis=1)

# Excluir colunas originais de revestimento
df = df.drop(colunas_revestimentoma, axis=1)

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_colunas_revestimentoma = df['RevestimentoMa'].value_counts(dropna=False)
print("Contagem de valores para AgrupamentoRevestimentoMa:")
print(contagem_valores_colunas_revestimentoma)

valores_unicos_colunas_revestimentoma = df['RevestimentoMa'].unique()
print("\nValores únicos para AgrupamentoRevestimentoMa:")
print(valores_unicos_colunas_revestimentoma)
# Out:
# Contagem de valores para AgrupamentoRevestimentoMa:
# RevestimentoMa
# 0_0.0            1758
# BrkFace_120.0      13
# BrkFace_180.0      11
# BrkFace_176.0      11
# BrkFace_200.0      10
#                  ...
# BrkFace_81.0        1
# Stone_0.0           1
# BrkCmn_183.0        1
# BrkFace_766.0       1
# BrkFace_382.0       1
# Name: count, Length: 592, dtype: int64
#
# Valores únicos para AgrupamentoRevestimentoMa:
# ['BrkFace_196.0' '0_0.0' 'BrkFace_162.0' 'BrkFace_350.0' 'Stone_186.0'
#  'Stone_240.0' 'Stone_286.0' 'Stone_306.0' 'BrkFace_212.0' 'BrkFace_180.0'
#  'BrkFace_380.0' 'BrkFace_281.0' 'Stone_640.0' 'Stone_200.0'
#  'BrkFace_246.0' 'Stone_132.0' 'BrkFace_650.0' 'BrkFace_101.0'
#  'BrkFace_412.0' 'BrkFace_272.0' 'BrkFace_456.0' 'BrkFace_1031.0'
#  'Stone_178.0' 'BrkFace_573.0' 'BrkFace_344.0' 'BrkFace_287.0'
#  'BrkFace_167.0' 'BrkFace_1115.0' 'BrkFace_40.0' 'BrkFace_104.0'
#  'BrkFace_576.0' 'BrkFace_443.0' 'Stone_468.0' 'BrkCmn_66.0'
# ...

# %%
# Substitua 'df' pelo nome real do seu DataFrame
coluna_agrupamento60 = 'RevestimentoMa'
num_clusters = 5  # Você pode ajustar o número de clusters conforme necessário

# Criar uma nova coluna com códigos de cluster
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df[coluna_agrupamento60 + '_Cluster'] = kmeans.fit_predict(df[coluna_agrupamento60].str.get_dummies('_'))

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_status_revsma = df['RevestimentoMa_Cluster'].value_counts(dropna=False)
print("Contagem de valores para RevestimentoMa_Cluster:")
print(contagem_valores_status_revsma )

valores_unicos_status_revsma  = df['RevestimentoMa_Cluster'].unique()
print("\nValores únicos para RevestimentoMa_Cluster:")
print(valores_unicos_status_revsma )
# Out:
# Contagem de valores para RevestimentoMa_Cluster:
# RevestimentoMa_Cluster
# 1    1766
# 2     862
# 0     274
# 3      13
# 4       4
# Name: count, dtype: int64
#
# Valores únicos para RevestimentoMa_Cluster:
# [2 1 0 3 4]
# C:\Users\psyte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_revestimento = ['EstiloTelhado', 'MaterialTelhado', 'ExteriorPrimario',
                        'ExteriorSecundario']

# Criar uma nova coluna com a concatenação dos valores das colunas de revestimento
df['Revestimento'] = df[colunas_revestimento].astype(str).agg('_'.join, axis=1)

# Excluir colunas originais de revestimento
df = df.drop(colunas_revestimento, axis=1)

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_colunas_revestimento = df['Revestimento'].value_counts(dropna=False)
print("Contagem de valores para AgrupamentoRevestimento:")
print(contagem_valores_colunas_revestimento)

valores_unicos_colunas_revestimento = df['Revestimento'].unique()
print("\nValores únicos para AgrupamentoRevestimento:")
print(valores_unicos_colunas_revestimento)
# Out:
# Contagem de valores para AgrupamentoRevestimento:
# Revestimento
# Gable_CompShg_VinylSd_VinylSd    833
# Gable_CompShg_MetalSd_MetalSd    351
# Gable_CompShg_HdBoard_HdBoard    295
# Gable_CompShg_Wd Sdng_Wd Sdng    261
# Hip_CompShg_VinylSd_VinylSd      164
#                                 ...
# Gable_WdShngl_HdBoard_HdBoard      1
# Gable_CompShg_VinylSd_Stucco       1
# Gable_CompShg_AsbShng_Stucco       1
# Gable_CompShg_CemntBd_Wd Sdng      1
# Gable_CompShg_CBlock_VinylSd       1
# Name: count, Length: 155, dtype: int64
#
# Valores únicos para AgrupamentoRevestimento:
# ['Gable_CompShg_VinylSd_VinylSd' 'Gable_CompShg_MetalSd_MetalSd'
#  'Gable_CompShg_Wd Sdng_Wd Shng' 'Gable_CompShg_HdBoard_HdBoard'
#  'Gable_CompShg_BrkFace_Wd Shng' 'Hip_CompShg_HdBoard_HdBoard'
#  'Hip_CompShg_WdShing_Wd Shng' 'Hip_CompShg_HdBoard_Plywood'
#  'Hip_CompShg_MetalSd_MetalSd' 'Gable_CompShg_Wd Sdng_Wd Sdng'
#  'Hip_CompShg_BrkFace_Plywood' 'Hip_CompShg_VinylSd_VinylSd'
# ...

# %%
# Substitua 'df' pelo nome real do seu DataFrame
coluna_agrupamento6 = 'Revestimento'
num_clusters = 10  # Você pode ajustar o número de clusters conforme necessário

# Criar uma nova coluna com códigos de cluster
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df[coluna_agrupamento6 + '_Cluster'] = kmeans.fit_predict(df[coluna_agrupamento6].str.get_dummies('_'))

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_status_revs = df['Revestimento_Cluster'].value_counts(dropna=False)
print("Contagem de valores para Revestimento_Cluster:")
print(contagem_valores_status_revs)

valores_unicos_status_revs = df['Revestimento_Cluster'].unique()
print("\nValores únicos para Revestimento_Cluster:")
print(valores_unicos_status_revs)
# Out:
# C:\Users\psyte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Contagem de valores para Revestimento_Cluster:
# Revestimento_Cluster
# 2    859
# 3    377
# 1    342
# 0    333
# 4    313
# 6    257
# 8    170
# 5    124
# 7    103
# 9     41
# Name: count, dtype: int64
#
# Valores únicos para Revestimento_Cluster:
# [2 3 0 4 7 1 9 8 5 6]

# %%
valores_unicos_lar= df['Lareiras'].unique()
contagem_valores_lar = df['Lareiras'].value_counts(dropna=False)
print(contagem_valores_lar)
print(valores_unicos_lar)

valores_unicos_qualar= df['QualidadeLareira'].unique()
contagem_valores_qualar = df['QualidadeLareira'].value_counts(dropna=False)
print(contagem_valores_qualar)
print(valores_unicos_qualar)
# Out:
# Lareiras
# 0    1420
# 1    1268
# 2     219
# 3      11
# 4       1
# Name: count, dtype: int64
# [0 1 2 3 4]
# QualidadeLareira
# NaN    1420
# Gd      744
# TA      592
# Fa       74
# Po       46
# Ex       43
# Name: count, dtype: int64
# [nan 'TA' 'Gd' 'Fa' 'Ex' 'Po']

# %%
# Substitua 'df' pelo nome real do seu DataFrame
df['QualidadeLareira'] = df['QualidadeLareira'].fillna(0)

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_lareira = ['Lareiras', 'QualidadeLareira']

# Criar uma nova coluna com a concatenação dos valores das colunas de lareira
df['StatusLareira'] = df[colunas_lareira].astype(str).agg('_'.join, axis=1)

# Excluir colunas originais de lareira
df = df.drop(colunas_lareira, axis=1)

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_colunas_lareira = df['StatusLareira'].value_counts(dropna=False)
print("Contagem de valores para AgrupamentoLareira:")
print(contagem_valores_colunas_lareira)

valores_unicos_colunas_lareira = df['StatusLareira'].unique()
print("\nValores únicos para AgrupamentoLareira:")
print(valores_unicos_colunas_lareira)
# Out:
# Contagem de valores para AgrupamentoLareira:
# StatusLareira
# 0_0     1420
# 1_Gd     627
# 1_TA     495
# 2_Gd     112
# 2_TA      92
# 1_Fa      63
# 1_Po      46
# 1_Ex      37
# 2_Fa      10
# 3_Gd       5
# 2_Ex       5
# 3_TA       4
# 3_Ex       1
# 3_Fa       1
# 4_TA       1
# Name: count, dtype: int64
#
# Valores únicos para AgrupamentoLareira:
# ['0_0' '1_TA' '1_Gd' '2_TA' '2_Gd' '1_Fa' '1_Ex' '1_Po' '3_Gd' '2_Fa'
#  '3_Ex' '2_Ex' '3_Fa' '3_TA' '4_TA']

# %%
# Substitua 'df' pelo nome real do seu DataFrame
coluna_agrupamento7 = 'StatusLareira'

num_clusters = 7  # Você pode ajustar o número de clusters conforme necessário

# Criar uma nova coluna com códigos de cluster
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df[coluna_agrupamento7 + '_Cluster'] = kmeans.fit_predict(df[coluna_agrupamento7].str.get_dummies('_'))

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_status_garagem = df['StatusLareira_Cluster'].value_counts(dropna=False)
print("Contagem de valores para StatusLareira_Cluster:")
print(contagem_valores_status_garagem)

valores_unicos_status_garagem = df['StatusLareira_Cluster'].unique()
print("\nValores únicos para StatusLareira_Cluster:")
print(valores_unicos_status_garagem)
# Out:
# C:\Users\psyte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Contagem de valores para StatusLareira_Cluster:
# StatusLareira_Cluster
# 0    1420
# 1     632
# 2     500
# 3     117
# 5     112
# 4      92
# 6      46
# Name: count, dtype: int64
#
# Valores únicos para StatusLareira_Cluster:
# [0 2 1 4 3 5 6]

# %%
valores_unicos_rua= df['Rua'].unique()
contagem_valores_rua = df['Rua'].value_counts(dropna=False)
print(contagem_valores_rua)
print(valores_unicos_rua)

valores_unicos_viela= df['Viela'].unique()
contagem_valores_viela = df['Viela'].value_counts(dropna=False)
print(contagem_valores_viela)
print(valores_unicos_viela)
# Out:
# Rua
# Pave    2907
# Grvl      12
# Name: count, dtype: int64
# ['Pave' 'Grvl']
# Viela
# NaN     2721
# Grvl     120
# Pave      78
# Name: count, dtype: int64
# [nan 'Grvl' 'Pave']

# %%
df = df.drop(['Viela'], axis=1)

# %%
valores_unicos_cojf= df['ConfigLote'].unique()
contagem_valores_cojf = df['ConfigLote'].value_counts(dropna=False)
print(contagem_valores_cojf)
print(valores_unicos_cojf)

valores_unicos_decl= df['DeclividadeTerreno'].unique()
contagem_valores_decl = df['DeclividadeTerreno'].value_counts(dropna=False)
print(contagem_valores_decl)
print(valores_unicos_decl)
# Out:
# ConfigLote
# Inside     2133
# Corner      511
# CulDSac     176
# FR2          85
# FR3          14
# Name: count, dtype: int64
# ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# DeclividadeTerreno
# Gtl    2778
# Mod     125
# Sev      16
# Name: count, dtype: int64
# ['Gtl' 'Mod' 'Sev']

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_configdeclividade = ['ConfigLote', 'DeclividadeTerreno']

# Criar uma nova coluna com a concatenação dos valores das colunas de ConfigLote e DeclividadeTerreno
df['ConfigDeclividade'] = df[colunas_configdeclividade].astype(str).agg('_'.join, axis=1)

# Excluir colunas originais de ConfigLote e DeclividadeTerreno
df = df.drop(colunas_configdeclividade, axis=1)

# Substitua 'df' pelo nome real do seu DataFrame
coluna_agrupamento10 = 'ConfigDeclividade'

num_clusters = 10 # Você pode ajustar o número de clusters conforme necessário

# Criar uma nova coluna com códigos de cluster
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df[coluna_agrupamento10 + '_Cluster'] = kmeans.fit_predict(df[coluna_agrupamento10].str.get_dummies('_'))

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_colunas_endereco = df['ConfigDeclividade_Cluster'].value_counts(dropna=False)
print("Contagem de valores para ConfigDeclividade_Cluster:")
print(contagem_valores_colunas_endereco)

valores_unicos_colunas_endereco = df['ConfigDeclividade_Cluster'].unique()
print("\nValores únicos para ConfigDeclividade_Cluster:")
print(valores_unicos_colunas_endereco)
# Out:
# Contagem de valores para ConfigDeclividade_Cluster:
# ConfigDeclividade_Cluster
# 1    2023
# 0     496
# 2     163
# 3     103
# 4      84
# 5      15
# 6      14
# 9       8
# 7       7
# 8       6
# Name: count, dtype: int64
#
# Valores únicos para ConfigDeclividade_Cluster:
# [1 4 0 2 5 3 8 9 6 7]
# C:\Users\psyte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
valores_unicos_fren= df['FrenteLote'].unique()
contagem_valores_fren = df['FrenteLote'].value_counts(dropna=False)
print(contagem_valores_fren)
print(valores_unicos_fren)

valores_unicos_area= df['AreaLote'].unique()
contagem_valores_area = df['AreaLote'].value_counts(dropna=False)
print(contagem_valores_area)
print(valores_unicos_area)
# Out:
# FrenteLote
# NaN      486
# 60.0     276
# 80.0     137
# 70.0     133
# 50.0     117
#         ...
# 111.0      1
# 138.0      1
# 182.0      1
# 168.0      1
# 133.0      1
# Name: count, Length: 129, dtype: int64
# [ 65.  80.  68.  60.  84.  85.  75.  nan  51.  50.  70.  91.  72.  66.
#  101.  57.  44. 110.  98.  47. 108. 112.  74. 115.  61.  48.  33.  52.
#  100.  24.  89.  63.  76.  81.  95.  69.  21.  32.  78. 121. 122.  40.
#  105.  73.  77.  64.  94.  34.  90.  55.  88.  82.  71. 120. 107.  92.
#  134.  62.  86. 141.  97.  54.  41.  79. 174.  99.  67.  83.  43. 103.
#   93.  30. 129. 140.  35.  37. 118.  87. 116. 150. 111.  49.  96.  59.
#   36.  56. 102.  58.  38. 109. 130.  53. 137.  45. 106. 104.  42.  39.
#  144. 114. 128. 149. 313. 168. 182. 138. 160. 152. 124. 153.  46.  26.
#   25. 119.  31.  28. 117. 113. 125. 135. 136.  22. 123. 195. 155. 126.
#  200. 131. 133.]
# AreaLote
# 9600     44
# 7200     43
# 6000     34
# 9000     29
# 10800    25
#          ..
# ...

# %%
valores_unicos_form= df['FormatoLote'].unique()
contagem_valores_form = df['FormatoLote'].value_counts(dropna=False)
print(contagem_valores_form)
print(valores_unicos_form)

valores_unicos_con= df['ContornoTerreno'].unique()
contagem_valores_con = df['ContornoTerreno'].value_counts(dropna=False)
print(contagem_valores_con)
print(valores_unicos_con)
# Out:
# FormatoLote
# Reg    1859
# IR1     968
# IR2      76
# IR3      16
# Name: count, dtype: int64
# ['Reg' 'IR1' 'IR2' 'IR3']
# ContornoTerreno
# Lvl    2622
# HLS     120
# Bnk     117
# Low      60
# Name: count, dtype: int64
# ['Lvl' 'Bnk' 'Low' 'HLS']

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_verificar_nan = ['AreaLote', 'FrenteLote', 'FormatoLote', 'ContornoTerreno']

# Verificar e contar NaN em cada coluna usada para criar 'Lote'
for coluna in colunas_verificar_nan:
    quantidade_nan = df[coluna].isna().sum()
    print(f"A coluna {coluna} tem {quantidade_nan} valores NaN.")
# Out:
# A coluna AreaLote tem 0 valores NaN.
# A coluna FrenteLote tem 486 valores NaN.
# A coluna FormatoLote tem 0 valores NaN.
# A coluna ContornoTerreno tem 0 valores NaN.

# %%
# Substitua 'df' pelo nome real do seu DataFrame
df['FrenteLote'] = df['FrenteLote'].fillna(df['FrenteLote'].mean())

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_lote = ['FormatoLote', 'ContornoTerreno']

# Criar uma nova coluna com a concatenação dos valores das colunas de lote
df['InfoLote'] = df[colunas_lote].astype(str).agg('_'.join, axis=1)

# Excluir colunas originais de lote
df = df.drop(colunas_lote, axis=1)

# Substitua 'df' pelo nome real do seu DataFrame
coluna_agrupamento11 = 'InfoLote'

num_clusters = 10 # Você pode ajustar o número de clusters conforme necessário

# Criar uma nova coluna com códigos de cluster
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df[coluna_agrupamento11 + '_Cluster'] = kmeans.fit_predict(df[coluna_agrupamento11].str.get_dummies('_'))

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_colunas_lote = df['InfoLote_Cluster'].value_counts(dropna=False)
print("Contagem de valores para InfoLote_Cluster:")
print(contagem_valores_colunas_lote)

valores_unicos_colunas_lote = df['InfoLote_Cluster'].unique()
print("\nValores únicos para InfoLote_Cluster:")
print(valores_unicos_colunas_lote)
# Out:
# C:\Users\psyte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Contagem de valores para InfoLote_Cluster:
# InfoLote_Cluster
# 1    1728
# 0     824
# 3      83
# 2      83
# 4      60
# 6      37
# 5      34
# 8      33
# 7      27
# 9      10
# Name: count, dtype: int64
#
# Valores únicos para InfoLote_Cluster:
# [1 0 4 3 7 6 5 2 8 9]

# %%
valores_unicos_mes= df['MesVenda'].unique()
contagem_valores_mes = df['MesVenda'].value_counts(dropna=False)
print(contagem_valores_mes)
print(valores_unicos_mes)

valores_unicos_ano= df['AnoVenda'].unique()
contagem_valores_ano = df['AnoVenda'].value_counts(dropna=False)
print(contagem_valores_ano)
print(valores_unicos_ano)
# Out:
# MesVenda
# 6     503
# 7     446
# 5     394
# 4     279
# 8     233
# 3     232
# 10    173
# 9     158
# 11    142
# 2     133
# 1     122
# 12    104
# Name: count, dtype: int64
# [ 2  5  9 12 10  8 11  4  1  7  3  6]
# AnoVenda
# 2007    692
# 2009    647
# 2008    622
# 2006    619
# 2010    339
# Name: count, dtype: int64
# [2008 2007 2006 2009 2010]

# %%
valores_unicos_tipovend= df['TipoVenda'].unique()
contagem_valores_tipovend = df['TipoVenda'].value_counts(dropna=False)
print(contagem_valores_tipovend)
print(valores_unicos_tipovend)

valores_unicos_condvend= df['CondicaoVenda'].unique()
contagem_valores_condvend = df['CondicaoVenda'].value_counts(dropna=False)
print(contagem_valores_condvend)
print(valores_unicos_condvend)
# Out:
# TipoVenda
# WD       2525
# New       239
# COD        87
# ConLD      26
# CWD        12
# ConLI       9
# ConLw       8
# Oth         7
# Con         5
# NaN         1
# Name: count, dtype: int64
# ['WD' 'New' 'COD' 'ConLD' 'ConLI' 'CWD' 'ConLw' 'Con' 'Oth' nan]
# CondicaoVenda
# Normal     2402
# Partial     245
# Abnorml     190
# Family       46
# Alloca       24
# AdjLand      12
# Name: count, dtype: int64
# ['Normal' 'Abnorml' 'Partial' 'AdjLand' 'Alloca' 'Family']

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_venda = ['TipoVenda', 'CondicaoVenda']

# Criar uma nova coluna com a concatenação dos valores das colunas de venda
df['InfoVenda'] = df[colunas_venda].astype(str).agg('_'.join, axis=1)

# Excluir colunas originais de venda
df = df.drop(colunas_venda, axis=1)

# Substitua 'df' pelo nome real do seu DataFrame
coluna_agrupamento12 = 'InfoVenda'

num_clusters = 15 # Você pode ajustar o número de clusters conforme necessário

# Criar uma nova coluna com códigos de cluster
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df[coluna_agrupamento12 + '_Cluster'] = kmeans.fit_predict(df[coluna_agrupamento12].str.get_dummies('_'))

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_colunas_venda = df['InfoVenda_Cluster'].value_counts(dropna=False)
print("Contagem de valores para InfoVenda_Cluster:")
print(contagem_valores_colunas_venda)

valores_unicos_colunas_venda = df['InfoVenda_Cluster'].unique()
print("\nValores únicos para InfoVenda_Cluster:")
print(valores_unicos_colunas_venda)
# Out:
# C:\Users\psyte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Contagem de valores para InfoVenda_Cluster:
# InfoVenda_Cluster
# 0     2314
# 1      239
# 2      139
# 4       46
# 3       46
# 5       39
# 6       24
# 7       21
# 10      12
# 11      10
# 9        7
# 14       6
# 12       6
# 13       5
# 8        5
# Name: count, dtype: int64
#
# Valores únicos para InfoVenda_Cluster:
# [ 0  2  1  4 10  5  6 14  3 13 11  9  8  7 12]

# %%
valores_unicos_qualger= df['QualidadeGeral'].unique()
contagem_valores_qualger = df['QualidadeGeral'].value_counts(dropna=False)
print(contagem_valores_qualger)
print(valores_unicos_qualger)

valores_unicos_condgeral= df['CondicaoGeral'].unique()
contagem_valores_condgeral = df['CondicaoGeral'].value_counts(dropna=False)
print(contagem_valores_condgeral)
print(valores_unicos_condgeral)
# Out:
# QualidadeGeral
# 5     825
# 6     731
# 7     600
# 8     342
# 4     226
# 9     107
# 3      40
# 10     31
# 2      13
# 1       4
# Name: count, dtype: int64
# [ 7  6  8  5  9  4 10  3  1  2]
# CondicaoGeral
# 5    1645
# 6     531
# 7     390
# 8     144
# 4     101
# 3      50
# 9      41
# 2      10
# 1       7
# Name: count, dtype: int64
# [5 8 6 7 4 2 3 9 1]

# %%
valores_unicos_quart= df['QuartosAcima'].unique()
contagem_valores_quart = df['QuartosAcima'].value_counts(dropna=False)
print(contagem_valores_quart)
print(valores_unicos_quart)

valores_unicos_coza= df['CozinhasAcima'].unique()
contagem_valores_coza = df['CozinhasAcima'].value_counts(dropna=False)
print(contagem_valores_coza)
print(valores_unicos_coza)
# Out:
# QuartosAcima
# 3    1596
# 2     742
# 4     400
# 1     103
# 5      48
# 6      21
# 0       8
# 8       1
# Name: count, dtype: int64
# [3 4 1 2 0 5 6 8]
# CozinhasAcima
# 1    2785
# 2     129
# 0       3
# 3       2
# Name: count, dtype: int64
# [1 2 3 0]

# %%
valores_unicos_qualcoz= df['QualidadeCozinha'].unique()
contagem_valores_qualcoz = df['QualidadeCozinha'].value_counts(dropna=False)
print(contagem_valores_qualcoz)
print(valores_unicos_qualcoz)

valores_unicos_totcomda= df['TotalComodosAcima'].unique()
contagem_valores_totcomda = df['TotalComodosAcima'].value_counts(dropna=False)
print(contagem_valores_totcomda)
print(valores_unicos_totcomda)
# Out:
# QualidadeCozinha
# TA     1492
# Gd     1151
# Ex      205
# Fa       70
# NaN       1
# Name: count, dtype: int64
# ['Gd' 'TA' 'Ex' 'Fa' nan]
# TotalComodosAcima
# 6     844
# 7     649
# 5     583
# 8     347
# 4     196
# 9     143
# 10     80
# 11     32
# 3      25
# 12     16
# 2       1
# 14      1
# 13      1
# 15      1
# Name: count, dtype: int64
# [ 8  6  7  9  5 11  4 10 12  3  2 14 13 15]

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_quartos_cozinhas = ['CozinhasAcima', 'QualidadeCozinha']

# Criar uma nova coluna com a concatenação dos valores das colunas de quartos, cozinhas, qualidade de cozinha e total de cômodos acima
df['Cozinhas_Qualidade_Total'] = df[colunas_quartos_cozinhas].astype(str).agg('_'.join, axis=1)

# Excluir colunas originais de quartos, cozinhas, qualidade de cozinha e total de cômodos acima
df = df.drop(colunas_quartos_cozinhas, axis=1)

# Substitua 'df' pelo nome real do seu DataFrame
coluna_agrupamento16 = 'Cozinhas_Qualidade_Total'

num_clusters = 200 # Você pode ajustar o número de clusters conforme necessário

# Criar uma nova coluna com códigos de cluster
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df[coluna_agrupamento16 + '_Cluster'] = kmeans.fit_predict(df[coluna_agrupamento16].str.get_dummies('_'))

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_colunas_qual_tot = df['Cozinhas_Qualidade_Total_Cluster'].value_counts(dropna=False)
print("Contagem de valores para Cozinhas_Qualidade_Total_Cluster:")
print(contagem_valores_colunas_qual_tot)

valores_unicos_colunas_qual_tot = df['Cozinhas_Qualidade_Total_Cluster'].unique()
print("\nValores únicos para Cozinhas_Qualidade_Total_Cluster:")
print(valores_unicos_colunas_qual_tot)
# Out:
# C:\Users\psyte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Contagem de valores para Cozinhas_Qualidade_Total_Cluster:
# Cozinhas_Qualidade_Total_Cluster
# 1    1372
# 0    1146
# 2     205
# 3     115
# 4      61
# 5       9
# 6       5
# 7       3
# 8       2
# 9       1
# Name: count, dtype: int64
#
# Valores únicos para Cozinhas_Qualidade_Total_Cluster:
# [0 1 3 2 4 5 8 6 7 9]
# C:\Users\psyte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:1152: ConvergenceWarning: Number of distinct clusters (10) found smaller than n_clusters (200). Possibly due to duplicate points in X.
# ...

# %%
valores_unicos_estcas= df['EstiloCasa'].unique()
contagem_valores_estcas = df['EstiloCasa'].value_counts(dropna=False)
print(contagem_valores_estcas)
print(valores_unicos_estcas)

valores_unicos_qualext= df['QualidadeExterior'].unique()
contagem_valores_qualext = df['QualidadeExterior'].value_counts(dropna=False)
print(contagem_valores_qualext)
print(valores_unicos_qualext)
# Out:
# EstiloCasa
# 1Story    1471
# 2Story     872
# 1.5Fin     314
# SLvl       128
# SFoyer      83
# 2.5Unf      24
# 1.5Unf      19
# 2.5Fin       8
# Name: count, dtype: int64
# ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# QualidadeExterior
# TA    1798
# Gd     979
# Ex     107
# Fa      35
# Name: count, dtype: int64
# ['Gd' 'TA' 'Ex' 'Fa']

# %%
valores_unicos_condext= df['CondicaoExterior'].unique()
contagem_valores_condext = df['CondicaoExterior'].value_counts(dropna=False)
print(contagem_valores_condext)
print(valores_unicos_condext)

valores_unicos_tipfunt= df['TipoFundacao'].unique()
contagem_valores_tipfunt = df['TipoFundacao'].value_counts(dropna=False)
print(contagem_valores_tipfunt)
print(valores_unicos_tipfunt)
# Out:
# CondicaoExterior
# TA    2538
# Gd     299
# Fa      67
# Ex      12
# Po       3
# Name: count, dtype: int64
# ['TA' 'Gd' 'Fa' 'Po' 'Ex']
# TipoFundacao
# PConc     1308
# CBlock    1235
# BrkTil     311
# Slab        49
# Stone       11
# Wood         5
# Name: count, dtype: int64
# ['PConc' 'CBlock' 'BrkTil' 'Wood' 'Slab' 'Stone']

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_qualidade_condicao = ['QualidadeExterior', 'CondicaoExterior']

# Criar uma nova coluna com a concatenação dos valores das colunas de estilo, qualidade exterior, condição exterior e tipo de fundação
df['Qualidade_Condicao'] = df[colunas_qualidade_condicao].astype(str).agg('_'.join, axis=1)

# Excluir colunas originais de estilo, qualidade exterior, condição exterior e tipo de fundação
df = df.drop(colunas_qualidade_condicao, axis=1)

# Substitua 'df' pelo nome real do seu DataFrame
coluna_agrupamento17 = 'Qualidade_Condicao'

num_clusters = 50 # Você pode ajustar o número de clusters conforme necessário

# Criar uma nova coluna com códigos de cluster
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df[coluna_agrupamento17 + '_Cluster'] = kmeans.fit_predict(df[coluna_agrupamento17].str.get_dummies('_'))

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_colunas_qual_est = df['Qualidade_Condicao_Cluster'].value_counts(dropna=False)
print("Contagem de valores para Qualidade_Condicao_Cluster:")
print(contagem_valores_colunas_qual_est)

valores_unicos_colunas_qual_est = df['Qualidade_Condicao_Cluster'].unique()
print("\nValores únicos para Qualidade_Condicao_Cluster:")
print(valores_unicos_colunas_qual_est)
# Out:
# C:\Users\psyte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Contagem de valores para Qualidade_Condicao_Cluster:
# Qualidade_Condicao_Cluster
# 0     1523
# 1     1120
# 42     107
# 3       75
# 4       61
# 5       19
# 6        6
# 7        3
# 9        2
# 8        2
# 10       1
# Name: count, dtype: int64
#
# Valores únicos para Qualidade_Condicao_Cluster:
# [ 1  0 42  4  3  5  6  9  7 10  8]
# ...

# %%
valores_unicos_recdiv= df['RecursoDiverso'].unique()
contagem_valores_recdiv = df['RecursoDiverso'].value_counts(dropna=False)
print(contagem_valores_recdiv)
print(valores_unicos_recdiv)

valores_unicos_valrec= df['ValorRecursoDiverso'].unique()
contagem_valores_valrec = df['ValorRecursoDiverso'].value_counts(dropna=False)
print(contagem_valores_valrec)
print(valores_unicos_valrec)
# Out:
# RecursoDiverso
# NaN     2814
# Shed      95
# Gar2       5
# Othr       4
# TenC       1
# Name: count, dtype: int64
# [nan 'Shed' 'Gar2' 'Othr' 'TenC']
# ValorRecursoDiverso
# 0        2816
# 400        18
# 500        13
# 450         9
# 600         8
# 2000        7
# 700         7
# 1500        3
# 650         3
# 1200        3
# 480         2
# 2500        2
# 3000        2
# 4500        2
# 750         1
# 900         1
# 17000       1
# 6500        1
# 1000        1
# 80          1
# 1512        1
# 455         1
# 460         1
# 490         1
# 1150        1
# 300         1
# 12500       1
# 8300        1
# 1400        1
# 560         1
# 620         1
# 54          1
# 1300        1
# 3500        1
# 800         1
# 15500       1
# 350         1
# 420         1
# Name: count, dtype: int64
# [    0   700   350   500   400   480   450 15500  1200   800  2000   600
#   3500  1300    54   620   560  1400  8300  1150  2500 12500  1500   300
# ...

# %%
# Substitua 'df' pelo nome real do seu DataFrame
df['RecursoDiverso'] = df['RecursoDiverso'].fillna(0)

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_recurso_valor = ['RecursoDiverso', 'ValorRecursoDiverso']

# Criar uma nova coluna com a concatenação dos valores das colunas de recurso diverso e valor do recurso diverso
df['Recurso_Valor'] = df[colunas_recurso_valor].astype(str).agg('_'.join, axis=1)

# Excluir colunas originais de recurso diverso e valor do recurso diverso
df = df.drop(colunas_recurso_valor, axis=1)

# Substitua 'df' pelo nome real do seu DataFrame
coluna_agrupamento18 = 'Recurso_Valor'

num_clusters = 15 # Você pode ajustar o número de clusters conforme necessário

# Criar uma nova coluna com códigos de cluster
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df[coluna_agrupamento18 + '_Cluster'] = kmeans.fit_predict(df[coluna_agrupamento18].str.get_dummies('_'))

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_colunas_qual_rec = df['Recurso_Valor_Cluster'].value_counts(dropna=False)
print("Contagem de valores para Recurso_Valor_Cluster:")
print(contagem_valores_colunas_qual_rec)

valores_unicos_colunas_qual_rec = df['Recurso_Valor_Cluster'].unique()
print("\nValores únicos para Recurso_Valor_Cluster:")
print(valores_unicos_colunas_qual_rec)
# Out:
# C:\Users\psyte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Contagem de valores para Recurso_Valor_Cluster:
# Recurso_Valor_Cluster
# 0     2815
# 13      21
# 1       18
# 3       13
# 2        9
# 4        8
# 8        7
# 5        7
# 6        5
# 10       3
# 7        3
# 12       3
# 9        3
# 11       2
# 14       2
# Name: count, dtype: int64
#
# Valores únicos para Recurso_Valor_Cluster:
# [ 0  8 13  3  1 11  2  6 10  5  4  7 14 12  9]

# %%
valores_unicos_pav= df['Pavimentacao'].unique()
contagem_valores_pav = df['Pavimentacao'].value_counts(dropna=False)
print(contagem_valores_pav)
print(valores_unicos_pav)

valores_unicos_cerc= df['Cerca'].unique()
contagem_valores_cerc = df['Cerca'].value_counts(dropna=False)
print(contagem_valores_cerc)
print(valores_unicos_cerc)
# Out:
# Pavimentacao
# Y    2641
# N     216
# P      62
# Name: count, dtype: int64
# ['Y' 'N' 'P']
# Cerca
# NaN      2348
# MnPrv     329
# GdPrv     118
# GdWo      112
# MnWw       12
# Name: count, dtype: int64
# [nan 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']

# %%
df = df.drop(['Cerca'], axis=1)

# %%
valores_unicos_zone= df['Zoneamento'].unique()
contagem_valores_zone = df['Zoneamento'].value_counts(dropna=False)
print(contagem_valores_zone)
print(valores_unicos_zone)

valores_unicos_utl= df['Utilidades'].unique()
contagem_valores_utl = df['Utilidades'].value_counts(dropna=False)
print(contagem_valores_utl)
print(valores_unicos_utl)

valores_unicos_func= df['Funcionalidade'].unique()
contagem_valores_func = df['Funcionalidade'].value_counts(dropna=False)
print(contagem_valores_func)
print(valores_unicos_func)
# Out:
# Zoneamento
# RL         2265
# RM          460
# FV          139
# RH           26
# C (all)      25
# NaN           4
# Name: count, dtype: int64
# ['RL' 'RM' 'C (all)' 'FV' 'RH' nan]
# Utilidades
# AllPub    2916
# NaN          2
# NoSeWa       1
# Name: count, dtype: int64
# ['AllPub' 'NoSeWa' nan]
# Funcionalidade
# Typ     2717
# Min2      70
# Min1      65
# Mod       35
# Maj1      19
# Maj2       9
# Sev        2
# NaN        2
# Name: count, dtype: int64
# ['Typ' 'Min1' 'Maj1' 'Min2' 'Mod' 'Maj2' 'Sev' nan]

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_zoneamento_utilidades_funcionalidade = ['Zoneamento', 'Utilidades', 'Funcionalidade']

# Criar uma nova coluna com a concatenação dos valores das colunas de zoneamento, utilidades e funcionalidade
df['Zoneamento_Utilidades_Funcionalidade'] = df[colunas_zoneamento_utilidades_funcionalidade].astype(str).agg('_'.join, axis=1)

# Excluir colunas originais de zoneamento, utilidades e funcionalidade
df = df.drop(colunas_zoneamento_utilidades_funcionalidade, axis=1)

# Substitua 'df' pelo nome real do seu DataFrame
coluna_agrupamento20 = 'Zoneamento_Utilidades_Funcionalidade'

num_clusters = 20 # Você pode ajustar o número de clusters conforme necessário

# Criar uma nova coluna com códigos de cluster
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df[coluna_agrupamento20 + '_Cluster'] = kmeans.fit_predict(df[coluna_agrupamento20].str.get_dummies('_'))

# Exibindo contagem de valores únicos e valores únicos para a nova coluna
contagem_valores_colunas_qual_ZON = df['Zoneamento_Utilidades_Funcionalidade_Cluster'].value_counts(dropna=False)
print("Contagem de valores para Zoneamento_Utilidades_Funcionalidade_Cluster:")
print(contagem_valores_colunas_qual_ZON)

valores_unicos_colunas_qual_ZON = df['Zoneamento_Utilidades_Funcionalidade_Cluster'].unique()
print("\nValores únicos para Zoneamento_Utilidades_Funcionalidade_Cluster:")
print(valores_unicos_colunas_qual_ZON)
# Out:
# Contagem de valores para Zoneamento_Utilidades_Funcionalidade_Cluster:
# Zoneamento_Utilidades_Funcionalidade_Cluster
# 0     2115
# 1      417
# 3      137
# 4       54
# 2       54
# 7       26
# 5       25
# 10      22
# 6       14
# 11      10
# 8       10
# 9        8
# 13       7
# 12       5
# 14       4
# 17       4
# 15       4
# 19       1
# 18       1
# 16       1
# Name: count, dtype: int64
#
# Valores únicos para Zoneamento_Utilidades_Funcionalidade_Cluster:
# [ 0  8  1  4 10  3  9  2 13 11  7  5 14 12  6 19 17 18 15 16]
# C:\Users\psyte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
print(df.columns)
display(df)
# Out:
# Index(['ClasseDeConstrução', 'FrenteLote', 'AreaLote', 'Rua', 'TipoConstrucao',
#        'EstiloCasa', 'QualidadeGeral', 'CondicaoGeral', 'AnoConstrucao',
#        'AnoRemodelacao', 'TipoFundacao', 'AreaAcabadaPorao1',
#        'AreaAcabadaPorao2', 'AreaNaoAcabadaPorao', 'AreaTotalPorao',
#        '1oAndarSF', '2oAndarSF', 'AreaBaixaQualidadeAcabamento', 'AreaViva',
#        'BanheirosPorao', 'MeioBanheiroPorao', 'BanheirosCompletos',
#        'MeioBanheiros', 'QuartosAcima', 'TotalComodosAcima', 'Pavimentacao',
#        'DeckMadeiraSF', 'VarandaAbertaSF', 'VarandaFechadaSF',
#        'Varanda3EstacoesSF', 'VarandaTelaSF', 'MesVenda', 'AnoVenda',
#        'SalePrice', 'StatusPiscina_Cluster', 'StatusGaragem',
#        'StatusGaragem_Cluster', 'MediaPorao', 'MediaPorao_Cluster',
#        'AgrupamentoLocal', 'AgrupamentoLocal_Cluster',
#        'AgrupamentoAquecimento', 'AgrupamentoAquecimento_Cluster',
#        'RevestimentoMa', 'RevestimentoMa_Cluster', 'Revestimento',
# ...

# %%
# Substitua 'df' pelo nome real do seu DataFrame
colunas_excluir = ['StatusGaragem', 'InfoLote', 'InfoVenda', 'RevestimentoMa',
                   'MediaPorao', 'Qualidade_Condicao', 'InfoLote', 'InfoVenda',
                   'AgrupamentoLocal', 'AgrupamentoAquecimento', 'Revestimento', 'StatusLareira', 'ConfigDeclividade', 
                 'Cozinhas_Qualidade_Total', 'Qualidade_Condicao', 'Recurso_Valor', 'Zoneamento_Utilidades_Funcionalidade']

# Excluir as colunas mencionadas
df = df.drop(colunas_excluir, axis=1)

# Exibir as colunas restantes
print(df.columns)
display(df)
# Out:
# Index(['ClasseDeConstrução', 'FrenteLote', 'AreaLote', 'Rua', 'TipoConstrucao',
#        'EstiloCasa', 'QualidadeGeral', 'CondicaoGeral', 'AnoConstrucao',
#        'AnoRemodelacao', 'TipoFundacao', 'AreaAcabadaPorao1',
#        'AreaAcabadaPorao2', 'AreaNaoAcabadaPorao', 'AreaTotalPorao',
#        '1oAndarSF', '2oAndarSF', 'AreaBaixaQualidadeAcabamento', 'AreaViva',
#        'BanheirosPorao', 'MeioBanheiroPorao', 'BanheirosCompletos',
#        'MeioBanheiros', 'QuartosAcima', 'TotalComodosAcima', 'Pavimentacao',
#        'DeckMadeiraSF', 'VarandaAbertaSF', 'VarandaFechadaSF',
#        'Varanda3EstacoesSF', 'VarandaTelaSF', 'MesVenda', 'AnoVenda',
#        'SalePrice', 'StatusPiscina_Cluster', 'StatusGaragem_Cluster',
#        'MediaPorao_Cluster', 'AgrupamentoLocal_Cluster',
#        'AgrupamentoAquecimento_Cluster', 'RevestimentoMa_Cluster',
#        'Revestimento_Cluster', 'StatusLareira_Cluster',
#        'ConfigDeclividade_Cluster', 'InfoLote_Cluster', 'InfoVenda_Cluster',
# ...

# %%
# Verificar valores NaN em cada coluna
nan_info = df.isnull().sum()

# Calcular a proporção de NaN em relação ao total de linhas
nan_ratio = nan_info / len(df)

# Criar um DataFrame para exibir as informações
nan_df = pd.DataFrame({
    'Coluna': nan_info.index,
    'Quantidade_NaN': nan_info.values,
    'Proporcao_NaN': nan_ratio.values
})

# Filtrar apenas as colunas com valores NaN
nan_df = nan_df[nan_df['Quantidade_NaN'] > 0]
pd.set_option('display.max_rows', None)
# Visualizar o DataFrame resultante
display(nan_df)
pd.reset_option('display.max_rows', None)
# Out:
#                  Coluna  Quantidade_NaN  Proporcao_NaN
# 11    AreaAcabadaPorao1               1       0.000343
# 12    AreaAcabadaPorao2               1       0.000343
# 13  AreaNaoAcabadaPorao               1       0.000343
# 14       AreaTotalPorao               1       0.000343
# 19       BanheirosPorao               2       0.000685
# 20    MeioBanheiroPorao               2       0.000685
# 33            SalePrice            1459       0.499829

# %%
# Lista das colunas indicadas
colunas_a_calcular = ['AreaAcabadaPorao1', 'AreaAcabadaPorao2', 'AreaNaoAcabadaPorao', 'AreaTotalPorao', 'BanheirosPorao', 'MeioBanheiroPorao']

# Calculando a média
media_colunas = train[colunas_a_calcular].mean()

# Calculando a moda
moda_colunas = train[colunas_a_calcular].mode().iloc[0]

# Exibindo os resultados
print("Média das colunas:")
print(media_colunas)

print("\nModa das colunas:")
print(moda_colunas)
# Out:
# Média das colunas:
# AreaAcabadaPorao1       443.639726
# AreaAcabadaPorao2        46.549315
# AreaNaoAcabadaPorao     567.240411
# AreaTotalPorao         1057.429452
# BanheirosPorao            0.425342
# MeioBanheiroPorao         0.057534
# dtype: float64
#
# Moda das colunas:
# AreaAcabadaPorao1      0
# AreaAcabadaPorao2      0
# AreaNaoAcabadaPorao    0
# AreaTotalPorao         0
# BanheirosPorao         0
# MeioBanheiroPorao      0
# Name: 0, dtype: int64

# %%
# Preencher NaN com a média
df['AreaAcabadaPorao1'].fillna(train['AreaAcabadaPorao1'].mean(), inplace=True)
df['AreaAcabadaPorao2'].fillna(train['AreaAcabadaPorao2'].mean(), inplace=True)
df['AreaNaoAcabadaPorao'].fillna(train['AreaNaoAcabadaPorao'].mean(), inplace=True)
df['AreaTotalPorao'].fillna(train['AreaTotalPorao'].mean(), inplace=True)

# Preencher NaN com a moda
df['BanheirosPorao'].fillna(train['BanheirosPorao'].mode().iloc[0], inplace=True)
df['MeioBanheiroPorao'].fillna(train['MeioBanheiroPorao'].mode().iloc[0], inplace=True)

# %%
# Verificar valores NaN em cada coluna
nan_info = df.isnull().sum()

# Calcular a proporção de NaN em relação ao total de linhas
nan_ratio = nan_info / len(df)

# Criar um DataFrame para exibir as informações
nan_df = pd.DataFrame({
    'Coluna': nan_info.index,
    'Quantidade_NaN': nan_info.values,
    'Proporcao_NaN': nan_ratio.values
})

# Filtrar apenas as colunas com valores NaN
nan_df = nan_df[nan_df['Quantidade_NaN'] > 0]
pd.set_option('display.max_rows', None)
# Visualizar o DataFrame resultante
display(nan_df)
pd.reset_option('display.max_rows', None)
# Out:
#        Coluna  Quantidade_NaN  Proporcao_NaN
# 33  SalePrice            1459       0.499829

# %%
colunas_categoricas = df.select_dtypes(include=['object']).columns

# Exibir as colunas categóricas
print(colunas_categoricas)
# Out:
# Index(['Rua', 'TipoConstrucao', 'EstiloCasa', 'TipoFundacao', 'Pavimentacao',
#        'StatusPiscina_Cluster'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# Substitua 'df' pelo nome real do seu DataFrame
colunas_cluster = [
    'StatusPiscina_Cluster', 'StatusGaragem_Cluster', 'Rua', 'TipoConstrucao',
    'MediaPorao_Cluster', 'AgrupamentoLocal_Cluster', 'EstiloCasa', 'TipoFundacao', 'Pavimentacao',
    'AgrupamentoAquecimento_Cluster', 'RevestimentoMa_Cluster',
    'Revestimento_Cluster', 'StatusLareira_Cluster',
    'ConfigDeclividade_Cluster', 'InfoLote_Cluster', 'InfoVenda_Cluster',
    'Cozinhas_Qualidade_Total_Cluster', 'Qualidade_Condicao_Cluster',
    'Recurso_Valor_Cluster', 'Zoneamento_Utilidades_Funcionalidade_Cluster'
]

# Crie um objeto OneHotEncoder
encoder = OneHotEncoder(sparse=False, drop='first')

# Ajuste e transforme as colunas do tipo 'Cluster' usando o encoder
df_encoded_cluster = pd.DataFrame(encoder.fit_transform(df[colunas_cluster]))

# Atribua nomes às novas colunas dummy
df_encoded_cluster.columns = encoder.get_feature_names_out(colunas_cluster)

# Redefina os índices dos DataFrames antes da concatenação
df_encoded_cluster.reset_index(drop=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# Concatene as colunas dummy ao DataFrame original e remova as colunas 'Cluster' originais
df_encoded = pd.concat([df, df_encoded_cluster], axis=1).drop(columns=colunas_cluster)

# Exiba as primeiras linhas do DataFrame resultante
df_encoded.head()
# Out:
# C:\Users\psyte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#    ClasseDeConstrução  FrenteLote  AreaLote  QualidadeGeral  CondicaoGeral  \
# 0                  60        65.0      8450               7              5
# 1                  20        80.0      9600               6              8
# 2                  60        68.0     11250               7              5
# 3                  70        60.0      9550               7              5
# 4                  60        84.0     14260               8              5
#
#    AnoConstrucao  AnoRemodelacao  AreaAcabadaPorao1  AreaAcabadaPorao2  \
# 0           2003            2003              706.0                0.0
# ...

# %%
colunas_categoricas2 = df_encoded.select_dtypes(include=['object']).columns

# Exibir as colunas categóricas
print(colunas_categoricas2)
# Out:
# Index([], dtype='object')

# %%
df_Train = df_encoded.iloc[:1460, :]
df_Test = df_encoded.iloc[1460:, :]
df_Train.head()
# Out:
#    ClasseDeConstrução  FrenteLote  AreaLote  QualidadeGeral  CondicaoGeral  \
# 0                  60        65.0      8450               7              5
# 1                  20        80.0      9600               6              8
# 2                  60        68.0     11250               7              5
# 3                  70        60.0      9550               7              5
# 4                  60        84.0     14260               8              5
#
#    AnoConstrucao  AnoRemodelacao  AreaAcabadaPorao1  AreaAcabadaPorao2  \
# 0           2003            2003              706.0                0.0
# 1           1976            1976              978.0                0.0
# 2           2001            2002              486.0                0.0
# 3           1915            1970              216.0                0.0
# 4           2000            2000              655.0                0.0
#
#    AreaNaoAcabadaPorao  ...  Zoneamento_Utilidades_Funcionalidade_Cluster_10  \
# ...

# %%
df_Test.head()
# Out:
#       ClasseDeConstrução  FrenteLote  AreaLote  QualidadeGeral  CondicaoGeral  \
# 1460                  20        80.0     11622               5              6
# 1461                  20        81.0     14267               6              6
# 1462                  60        74.0     13830               5              5
# 1463                  60        78.0      9978               6              6
# 1464                 120        43.0      5005               8              5
#
#       AnoConstrucao  AnoRemodelacao  AreaAcabadaPorao1  AreaAcabadaPorao2  \
# 1460           1961            1961              468.0              144.0
# 1461           1958            1958              923.0                0.0
# 1462           1997            1998              791.0                0.0
# 1463           1998            1998              602.0                0.0
# 1464           1992            1992              263.0                0.0
#
#       AreaNaoAcabadaPorao  ...  \
# ...

# %%
df_encoded.to_csv('DF_PRONTO.csv', index=False)
df_Train.to_csv('df_Train_pronto.csv', index=False)
df_Test.to_csv('df_Test_pronto.csv', index=False)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
